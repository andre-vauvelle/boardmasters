# %% [markdown]
# # Bed simulation

# %%
"""
Bed counter-factual Simulation

Covers:

- Resources: Resource
- Resources: Container
- Waiting for other processes

Scenario:
    We are trying to assess if using a non-greedy approach would
     reduce the number of patients boarded to the wrong ward

- A patient arrives at the beds_correct - the logic!
beds = simulated_beds + remaining_beds

# If there are no beds in the correct specialty area irl
if remaining_beds=0:
    boarded = True
else:
    boarded = False
# If there are no beds in the simulation for the correct specialty area
if beds <= 0 | predicted_board:
    simulation_boarded = True
else:
    simulation_boarded = False

if simulation_boarded & boarded:
    wait for a bit
    leave
if simulation_boarded & not boarded:
    increment simulated beds
    wait for a bit
    leave
if not simulation_boarded & boarded:
    decrement simulation beds
    wait for a bit
if not simulation_boarded & not boarded:  # repeated for readability...
    wait for a bit
    leave
"""
import itertools
import random
import pandas as pd
import numpy as np
import simpy


RANDOM_SEED = 42
T_INTER = [5, 20]        # Create a patient every [min, max] minutes
SIM_TIME = 60*12*30          # Simulation time in minutes
NUMBER_OF_BEDS = 200

df = pd.read_csv('data.csv')
df['counter_mort'] = np.random.uniform(low=0, high=1, size=(df.shape[0],))
#df['counter_mort'] = np.random.lognormal(mean=0.3, sigma=1)
#df['counter_mort'] = df['counter_mort'].apply(lambda x: (1 if x > 1 else x))
df['predicted_boarded'] = df['counter_mort'].apply(lambda x: x > 0.5)
df['mort'] = df['days_survived'].apply(lambda x: x <= 30)
patients = df.to_dict(orient='records')

# Toy data
#patients = [{'transfers.subject_id': 1, 'icustay_los_total': 50, 'remaining_beds': 6, 'predicted_boarded': False},
#            {'transfers.subject_id': 2, 'icustay_los_total': 30, 'remaining_beds': 6, 'predicted_boarded': False}]


global simulated_beds
simulated_beds = 0
mortalityStore = []
agreementStore = []


def patient(env, beds_correct, **p):
    global simulated_beds
    print('%s arriving at ICU at %.1f' % (p['transfers.subject_id'], env.now))
    
    beds = simulated_beds + p['remaining_beds']
    print("beds",beds, simulated_beds)
    if p['icustay_boarder_initial'] == 1:
        boarded = True
    else:
        boarded = False

    # If there are no beds in the simulation for the correct specialty area
    if p['predicted_boarded']:
        simulation_boarded = True
    else:
        simulation_boarded = False
        print("Became false!", p['predicted_boarded'], beds)

    if simulation_boarded & boarded:
        print("Agreed boarding")
        agreementStore.append("Agreed boarding")
        mortalityStore.append(p['mort'])
        with beds_correct.request() as req:
            start = env.now
            # Request one of the beds
            yield req
            # Stay in a bed for a bit
            yield env.timeout(p['icustay_los_total'])
            print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))

    elif simulation_boarded & (not boarded):
        print("Disagree boarding")
        agreementStore.append("Disagree boarding")
        mortalityStore.append(p['counter_mort'])
        with beds_correct.request() as req:
            start = env.now
            simulated_beds += 1
            # Request one of the beds
            yield req
            # Stay in a bed for a bit
            yield env.timeout(p['icustay_los_total'])
            #simulated_beds -= 1
            print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))

    elif (not simulation_boarded) and boarded:
        print(beds)
        if beds > 0:
            print("Disagree not boarding, boarding")
            agreementStore.append("Disagree not boarding")
            mortalityStore.append(p['counter_mort'])
            with beds_correct.request() as req:
                start = env.now
                simulated_beds -= 1
                # Request one of the beds
                yield req
                # Stay in a bed for a bit
                yield env.timeout(p['icustay_los_total'])
                simulated_beds += 1
                print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))
        else:
            print("Not enough beds")
            agreementStore.append("Agreed boarding")
            mortalityStore.append(p['mort'])
            with beds_correct.request() as req:
                start = env.now
                # Request one of the beds
                yield req
                # Stay in a bed for a bit
                yield env.timeout(p['icustay_los_total'])
                print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))

            
    elif (not simulation_boarded) and (not boarded):
        if beds > 0:
            print("Agreed not boarding")
            agreementStore.append("Agreed not boarding")
            mortalityStore.append(p['mort'])
            with beds_correct.request() as req:
                start = env.now
                # Request one of the beds
                yield req
                # Stay in a bed for a bit
                yield env.timeout(p['icustay_los_total'])
                print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))
        else:
            print("Not enough beds, boarding")
            agreementStore.append("Agreed boarding")
            mortalityStore.append(p['mort'])
            with beds_correct.request() as req:
                start = env.now
                # Request one of the beds
                yield req
                # Stay in a bed for a bit
                yield env.timeout(p['icustay_los_total'])
                print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))




def patient_generator(env, beds_correct, patients):
    """Generate new patient that arrive at the ICU."""
    for i in itertools.count():
        yield env.timeout(random.randint(*T_INTER))
        p = random.sample(patients, 1)[0]
        #print_name = 'Simulation id {}'.format(i) #, Data id  %s' % (i, p['transfers.subject_id'])
        env.process(patient(env, beds_correct, **p))


# Create environment and start processes
env = simpy.Environment()
beds_correct = simpy.Resource(env, NUMBER_OF_BEDS)
#bed_boarded = simpy.Resource(env, 1, NUMBER_OF_BEDS)
env.process(patient_generator(env, beds_correct, patients)) #beds_boarded,

# Execute!
env.run(until=SIM_TIME)

print(simulated_beds)
# Out:
# /Users/andrevauvelle/anaconda3/envs/flask/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2548 arriving at ICU at 14.0
# beds 8 0
# Became false! False 8
# Agreed not boarding
# 29650 arriving at ICU at 19.0
# beds 2 0
# Disagree boarding
# 29650 left ward in 0.4 minutes.
# 8972 arriving at ICU at 30.0
# beds 5 1
# Became false! False 5
# 5
# Disagree not boarding, boarding
# 25837 arriving at ICU at 48.0
# beds 1 0
# Became false! False 1
# 1
# Disagree not boarding, boarding
# 8972 left ward in 22.2 minutes.
# 2548 left ward in 43.0 minutes.
# 83937 arriving at ICU at 66.0
# beds 4 0
# Disagree boarding
# 42555 arriving at ICU at 81.0
# beds 3 1
# Became false! False 3
# Agreed not boarding
# 24682 arriving at ICU at 86.0
# beds 4 1
# Became false! False 4
# Agreed not boarding
# 42555 left ward in 19.7 minutes.
# 51791 arriving at ICU at 106.0
# beds 2 1
# Became false! False 2
# Agreed not boarding
# 25837 left ward in 65.1 minutes.
# 46961 arriving at ICU at 121.0
# beds 10 2
# Became false! False 10
# Agreed not boarding
# 51791 left ward in 21.7 minutes.
# 19385 arriving at ICU at 130.0
# beds 4 2
# Became false! False 4
# Agreed not boarding
# 46961 left ward in 20.9 minutes.
# 24682 left ward in 56.4 minutes.
# 20534 arriving at ICU at 148.0
# beds 6 2
# Became false! False 6
# Agreed not boarding
# 19385 left ward in 24.5 minutes.
# 1901 arriving at ICU at 158.0
# beds 2 2
# Agreed boarding
# 82328 arriving at ICU at 176.0
# beds 3 2
# Agreed boarding
# 1901 left ward in 23.7 minutes.
# 83937 left ward in 125.9 minutes.
# 80106 arriving at ICU at 196.0
# beds 5 2
# Became false! False 5
# Agreed not boarding
# 82328 left ward in 32.8 minutes.
# 30234 arriving at ICU at 213.0
# beds 7 2
# Became false! False 7
# Agreed not boarding
# 85673 arriving at ICU at 220.0
# beds 2 2
# Agreed boarding
# 27760 arriving at ICU at 228.0
# beds 6 2
# Became false! False 6
# Agreed not boarding
# 80106 left ward in 35.3 minutes.
# 30234 left ward in 21.7 minutes.
# 49750 arriving at ICU at 238.0
# beds 2 2
# Agreed boarding
# 85673 left ward in 27.5 minutes.
# 41962 arriving at ICU at 249.0
# beds 5 2
# Became false! False 5
# Agreed not boarding
# 25814 arriving at ICU at 263.0
# beds 4 2
# Disagree boarding
# 25814 left ward in 1.1 minutes.
# 41962 left ward in 27.7 minutes.
# 13599 arriving at ICU at 282.0
# beds 4 3
# Agreed boarding
# 65824 arriving at ICU at 302.0
# beds 8 3
# Became false! False 8
# Agreed not boarding
# 11521 arriving at ICU at 316.0
# beds 6 3
# Became false! False 6
# Agreed not boarding
# 29949 arriving at ICU at 333.0
# beds 8 3
# Became false! False 8
# Agreed not boarding
# 11521 left ward in 21.7 minutes.
# 31183 arriving at ICU at 341.0
# beds 5 3
# Became false! False 5
# 5
# Disagree not boarding, boarding
# 49750 left ward in 111.1 minutes.
# 53397 arriving at ICU at 352.0
# beds 6 2
# Became false! False 6
# Agreed not boarding
# 50079 arriving at ICU at 365.0
# beds 4 2
# Disagree boarding
# 10677 arriving at ICU at 384.0
# beds 2 3
# Became false! False 2
# 2
# Disagree not boarding, boarding
# 50079 left ward in 29.7 minutes.
# 53397 left ward in 43.6 minutes.
# 65824 left ward in 95.6 minutes.
# 19911 arriving at ICU at 402.0
# beds 6 2
# Became false! False 6
# 6
# Disagree not boarding, boarding
# 29949 left ward in 69.7 minutes.
# 95324 arriving at ICU at 413.0
# beds 5 1
# Became false! False 5
# Agreed not boarding
# 3868 arriving at ICU at 429.0
# beds 7 1
# Became false! False 7
# Agreed not boarding
# 31183 left ward in 90.1 minutes.
# 18971 arriving at ICU at 447.0
# beds 2 2
# Agreed boarding
# 10677 left ward in 64.8 minutes.
# 13599 left ward in 173.3 minutes.
# 51195 arriving at ICU at 463.0
# beds 6 3
# Disagree boarding
# 51195 left ward in 0.4 minutes.
# 25630 arriving at ICU at 477.0
# beds 10 4
# Became false! False 10
# Agreed not boarding
# 20534 left ward in 339.5 minutes.
# 94886 arriving at ICU at 491.0
# beds 7 4
# Disagree boarding
# 58144 arriving at ICU at 503.0
# beds 9 5
# Became false! False 9
# Agreed not boarding
# 51823 arriving at ICU at 508.0
# beds 10 5
# Became false! False 10
# Agreed not boarding
# 95324 left ward in 96.4 minutes.
# 94886 left ward in 24.3 minutes.
# 93078 arriving at ICU at 522.0
# beds 10 5
# Disagree boarding
# 25630 left ward in 46.9 minutes.
# 58144 left ward in 26.6 minutes.
# 12828 arriving at ICU at 537.0
# beds 7 6
# Disagree boarding
# 28565 arriving at ICU at 550.0
# beds 8 7
# Became false! False 8
# 8
# Disagree not boarding, boarding
# 6953 arriving at ICU at 559.0
# beds 8 6
# Agreed boarding
# 27760 left ward in 340.7 minutes.
# 16449 arriving at ICU at 569.0
# beds 12 6
# Became false! False 12
# Agreed not boarding
# 5495 arriving at ICU at 578.0
# beds 7 6
# Disagree boarding
# 28565 left ward in 36.2 minutes.
# 12828 left ward in 52.7 minutes.
# 16139 arriving at ICU at 590.0
# beds 9 8
# Became false! False 9
# 9
# Disagree not boarding, boarding
# 51823 left ward in 94.2 minutes.
# 83093 arriving at ICU at 609.0
# beds 10 7
# Became false! False 10
# Agreed not boarding
# 99556 arriving at ICU at 619.0
# beds 11 7
# Became false! False 11
# Agreed not boarding
# 16449 left ward in 52.1 minutes.
# 18971 left ward in 182.3 minutes.
# 5495 left ward in 53.9 minutes.
# 16139 left ward in 41.9 minutes.
# 80033 arriving at ICU at 633.0
# beds 10 8
# Disagree boarding
# 99556 left ward in 21.6 minutes.
# 19991 arriving at ICU at 646.0
# beds 16 9
# Disagree boarding
# 6953 left ward in 91.1 minutes.
# 12365 arriving at ICU at 660.0
# beds 13 10
# Disagree boarding
# 63053 arriving at ICU at 668.0
# beds 13 11
# Disagree boarding
# 9026 arriving at ICU at 677.0
# beds 14 12
# Became false! False 14
# Agreed not boarding
# 83093 left ward in 76.3 minutes.
# 27553 arriving at ICU at 697.0
# beds 15 12
# Became false! False 15
# Agreed not boarding
# 12365 left ward in 44.3 minutes.
# 27553 left ward in 9.3 minutes.
# 27337 arriving at ICU at 707.0
# beds 26 12
# Disagree boarding
# 9026 left ward in 33.1 minutes.
# 50026 arriving at ICU at 718.0
# beds 16 13
# Became false! False 16
# Agreed not boarding
# 20969 arriving at ICU at 728.0
# beds 14 13
# Became false! False 14
# Agreed not boarding
# 93566 arriving at ICU at 733.0
# beds 16 13
# Disagree boarding
# 3868 left ward in 313.8 minutes.
# 3605 arriving at ICU at 747.0
# beds 17 14
# Became false! False 17
# Agreed not boarding
# 50026 left ward in 29.6 minutes.
# 3605 left ward in 15.7 minutes.
# 24692 arriving at ICU at 764.0
# beds 14 14
# Became false! False 14
# 14
# Disagree not boarding, boarding
# 402 arriving at ICU at 773.0
# beds 15 13
# Became false! False 15
# 15
# Disagree not boarding, boarding
# 27337 left ward in 69.2 minutes.
# 25395 arriving at ICU at 790.0
# beds 14 12
# Became false! False 14
# Agreed not boarding
# 43820 arriving at ICU at 807.0
# beds 12 12
# Became false! False 12
# 12
# Disagree not boarding, boarding
# 7761 arriving at ICU at 824.0
# beds 12 11
# Became false! False 12
# 12
# Disagree not boarding, boarding
# 402 left ward in 52.9 minutes.
# 29385 arriving at ICU at 829.0
# beds 15 11
# Became false! False 15
# Agreed not boarding
# 93078 left ward in 311.2 minutes.
# 3362 arriving at ICU at 839.0
# beds 13 11
# Became false! False 13
# 13
# Disagree not boarding, boarding
# 29385 left ward in 11.1 minutes.
# 43820 left ward in 33.8 minutes.
# 45672 arriving at ICU at 854.0
# beds 12 11
# Agreed boarding
# 3362 left ward in 16.7 minutes.
# 7761 left ward in 45.0 minutes.
# 71997 arriving at ICU at 871.0
# beds 19 13
# Disagree boarding
# 71997 left ward in 6.9 minutes.
# 57908 arriving at ICU at 883.0
# beds 15 14
# Disagree boarding
# 25395 left ward in 99.3 minutes.
# 48539 arriving at ICU at 899.0
# beds 17 15
# Became false! False 17
# Agreed not boarding
# 45672 left ward in 55.0 minutes.
# 70561 arriving at ICU at 913.0
# beds 19 15
# Disagree boarding
# 2133 arriving at ICU at 920.0
# beds 21 16
# Disagree boarding
# 93566 left ward in 187.4 minutes.
# 57908 left ward in 46.6 minutes.
# 24692 left ward in 167.9 minutes.
# 20969 left ward in 211.9 minutes.
# 84534 arriving at ICU at 940.0
# beds 21 18
# Disagree boarding
# 1860 arriving at ICU at 947.0
# beds 19 19
# Agreed boarding
# 22532 arriving at ICU at 952.0
# beds 24 19
# Disagree boarding
# 2133 left ward in 38.5 minutes.
# 2592 arriving at ICU at 970.0
# beds 22 20
# Disagree boarding
# 70561 left ward in 67.3 minutes.
# 21021 arriving at ICU at 983.0
# beds 22 21
# Disagree boarding
# 63053 left ward in 319.4 minutes.
# 84534 left ward in 48.9 minutes.
# 80033 left ward in 358.5 minutes.
# 1860 left ward in 48.9 minutes.
# 16194 arriving at ICU at 1003.0
# beds 22 22
# Agreed boarding
# 8522 arriving at ICU at 1010.0
# beds 24 22
# Became false! False 24
# 24
# Disagree not boarding, boarding
# 8228 arriving at ICU at 1018.0
# beds 23 21
# Disagree boarding
# 22532 left ward in 75.5 minutes.
# 21021 left ward in 45.4 minutes.
# 67920 arriving at ICU at 1035.0
# beds 27 22
# Became false! False 27
# Agreed not boarding
# 16194 left ward in 33.6 minutes.
# 8228 left ward in 27.8 minutes.
# 57496 arriving at ICU at 1048.0
# beds 25 22
# Became false! False 25
# Agreed not boarding
# 18727 arriving at ICU at 1065.0
# beds 25 22
# Disagree boarding
# 57496 left ward in 20.0 minutes.
# 19991 left ward in 429.5 minutes.
# 95582 arriving at ICU at 1077.0
# beds 26 23
# Became false! False 26
# Agreed not boarding
# 70084 arriving at ICU at 1085.0
# beds 24 23
# Became false! False 24
# Agreed not boarding
# 67920 left ward in 52.5 minutes.
# 8522 left ward in 87.5 minutes.
# 12212 arriving at ICU at 1102.0
# beds 26 24
# Agreed boarding
# 79132 arriving at ICU at 1110.0
# beds 26 24
# Disagree boarding
# 12212 left ward in 8.0 minutes.
# 42396 arriving at ICU at 1126.0
# beds 31 25
# Disagree boarding
# 70084 left ward in 50.1 minutes.
# 95582 left ward in 61.7 minutes.
# 4927 arriving at ICU at 1139.0
# beds 28 26
# Became false! False 28
# Agreed not boarding
# 18727 left ward in 78.1 minutes.
# 42396 left ward in 21.7 minutes.
# 48539 left ward in 252.2 minutes.
# 90861 arriving at ICU at 1159.0
# beds 27 26
# Disagree boarding
# 16406 arriving at ICU at 1167.0
# beds 28 27
# Became false! False 28
# Agreed not boarding
# 90861 left ward in 19.1 minutes.
# 2592 left ward in 208.6 minutes.
# 32810 arriving at ICU at 1183.0
# beds 27 27
# Became false! False 27
# 27
# Disagree not boarding, boarding
# 79132 left ward in 77.2 minutes.
# 52604 arriving at ICU at 1203.0
# beds 29 26
# Disagree boarding
# 16406 left ward in 52.1 minutes.
# 32810 left ward in 38.9 minutes.
# 81041 arriving at ICU at 1223.0
# beds 34 28
# Became false! False 34
# Agreed not boarding
# 11043 arriving at ICU at 1236.0
# beds 33 28
# Agreed boarding
# 27874 arriving at ICU at 1247.0
# beds 28 28
# Became false! False 28
# 28
# Disagree not boarding, boarding
# 25814 arriving at ICU at 1257.0
# beds 29 27
# Disagree boarding
# 25814 left ward in 1.1 minutes.
# 52604 left ward in 62.9 minutes.
# 44685 arriving at ICU at 1266.0
# beds 29 28
# Agreed boarding
# 22114 arriving at ICU at 1278.0
# beds 34 28
# Became false! False 34
# Agreed not boarding
# 81041 left ward in 55.5 minutes.
# 11043 left ward in 43.3 minutes.
# 63948 arriving at ICU at 1289.0
# beds 29 28
# Disagree boarding
# 22114 left ward in 18.3 minutes.
# 63948 left ward in 12.8 minutes.
# 9129 arriving at ICU at 1302.0
# beds 36 29
# Became false! False 36
# Agreed not boarding
# 11922 arriving at ICU at 1315.0
# beds 31 29
# Disagree boarding
# 81593 arriving at ICU at 1322.0
# beds 35 30
# Became false! False 35
# Agreed not boarding
# 4927 left ward in 185.0 minutes.
# 31903 arriving at ICU at 1327.0
# beds 31 30
# Became false! False 31
# Agreed not boarding
# 9129 left ward in 39.8 minutes.
# 7607 arriving at ICU at 1342.0
# beds 31 30
# Disagree boarding
# 44685 left ward in 81.5 minutes.
# 11922 left ward in 35.7 minutes.
# 31903 left ward in 32.0 minutes.
# 86773 arriving at ICU at 1359.0
# beds 34 31
# Disagree boarding
# 88518 arriving at ICU at 1370.0
# beds 34 32
# Became false! False 34
# Agreed not boarding
# 88518 left ward in 15.3 minutes.
# 87687 arriving at ICU at 1389.0
# beds 32 32
# Became false! False 32
# 32
# Disagree not boarding, boarding
# 3678 arriving at ICU at 1403.0
# beds 33 31
# Became false! False 33
# Agreed not boarding
# 3678 left ward in 0.8 minutes.
# 50417 arriving at ICU at 1421.0
# beds 38 31
# Disagree boarding
# 7607 left ward in 79.7 minutes.
# 91465 arriving at ICU at 1434.0
# beds 32 32
# Became false! False 32
# 32
# Disagree not boarding, boarding
# 50417 left ward in 25.3 minutes.
# 45226 arriving at ICU at 1449.0
# beds 35 31
# Disagree boarding
# 56769 arriving at ICU at 1458.0
# beds 33 32
# Became false! False 33
# 33
# Disagree not boarding, boarding
# 45226 left ward in 21.9 minutes.
# 84488 arriving at ICU at 1475.0
# beds 32 31
# Became false! False 32
# Agreed not boarding
# 87687 left ward in 89.5 minutes.
# 18205 arriving at ICU at 1480.0
# beds 35 32
# Became false! False 35
# Agreed not boarding
# 91465 left ward in 57.4 minutes.
# 60222 arriving at ICU at 1496.0
# beds 35 33
# Disagree boarding
# 92872 arriving at ICU at 1510.0
# beds 36 34
# Disagree boarding
# 60222 left ward in 18.3 minutes.
# 84488 left ward in 41.6 minutes.
# 14104 arriving at ICU at 1517.0
# beds 36 35
# Became false! False 36
# Agreed not boarding
# 18205 left ward in 44.0 minutes.
# 92872 left ward in 14.4 minutes.
# 42948 arriving at ICU at 1535.0
# beds 39 35
# Disagree boarding
# 56769 left ward in 77.8 minutes.
# 14634 arriving at ICU at 1552.0
# beds 42 37
# Became false! False 42
# Agreed not boarding
# 14104 left ward in 37.2 minutes.
# 13761 arriving at ICU at 1560.0
# beds 39 37
# Disagree boarding
# 28172 arriving at ICU at 1569.0
# beds 40 38
# Disagree boarding
# 42948 left ward in 37.0 minutes.
# 14634 left ward in 24.3 minutes.
# 43637 arriving at ICU at 1579.0
# beds 42 39
# Became false! False 42
# Agreed not boarding
# 13761 left ward in 19.9 minutes.
# 81593 left ward in 270.1 minutes.
# 71798 arriving at ICU at 1598.0
# beds 42 39
# Disagree boarding
# 30461 arriving at ICU at 1606.0
# beds 43 40
# Disagree boarding
# 68591 arriving at ICU at 1624.0
# beds 43 41
# Disagree boarding
# 81167 arriving at ICU at 1635.0
# beds 44 42
# Disagree boarding
# 86773 left ward in 283.3 minutes.
# 30461 left ward in 44.4 minutes.
# 8061 arriving at ICU at 1654.0
# beds 44 43
# Agreed boarding
# 81167 left ward in 27.6 minutes.
# 43637 left ward in 86.4 minutes.
# 97683 arriving at ICU at 1672.0
# beds 46 43
# Became false! False 46
# Agreed not boarding
# 71798 left ward in 77.8 minutes.
# 25749 arriving at ICU at 1677.0
# beds 46 43
# Became false! False 46
# Agreed not boarding
# 25749 left ward in 9.5 minutes.
# 45248 arriving at ICU at 1695.0
# beds 47 43
# Disagree boarding
# 28390 arriving at ICU at 1714.0
# beds 46 44
# Disagree boarding
# 45248 left ward in 26.7 minutes.
# 68591 left ward in 101.8 minutes.
# 61304 arriving at ICU at 1729.0
# beds 49 45
# Became false! False 49
# Agreed not boarding
# 23325 arriving at ICU at 1735.0
# beds 46 45
# Agreed boarding
# 27874 left ward in 489.3 minutes.
# 54783 arriving at ICU at 1752.0
# beds 47 46
# Disagree boarding
# 61304 left ward in 35.0 minutes.
# 45277 arriving at ICU at 1770.0
# beds 51 47
# Disagree boarding
# 28390 left ward in 61.0 minutes.
# 54783 left ward in 24.5 minutes.
# 88514 arriving at ICU at 1780.0
# beds 48 48
# Became false! False 48
# 48
# Disagree not boarding, boarding
# 28172 left ward in 211.4 minutes.
# 51418 arriving at ICU at 1785.0
# beds 47 47
# Became false! False 47
# Agreed not boarding
# 97683 left ward in 120.2 minutes.
# 76282 arriving at ICU at 1804.0
# beds 48 47
# Disagree boarding
# 16582 arriving at ICU at 1818.0
# beds 56 48
# Disagree boarding
# 25874 arriving at ICU at 1825.0
# beds 50 49
# Became false! False 50
# Agreed not boarding
# 51418 left ward in 41.2 minutes.
# 23096 arriving at ICU at 1832.0
# beds 52 49
# Disagree boarding
# 4843 arriving at ICU at 1848.0
# beds 50 50
# Became false! False 50
# 50
# Disagree not boarding, boarding
# 10388 arriving at ICU at 1855.0
# beds 52 49
# Became false! False 52
# Agreed not boarding
# 16582 left ward in 42.6 minutes.
# 23096 left ward in 29.8 minutes.
# 79671 arriving at ICU at 1868.0
# beds 50 49
# Became false! False 50
# 50
# Disagree not boarding, boarding
# 88514 left ward in 93.7 minutes.
# 31760 arriving at ICU at 1877.0
# beds 55 49
# Disagree boarding
# 10388 left ward in 22.1 minutes.
# 45277 left ward in 115.3 minutes.
# 88587 arriving at ICU at 1886.0
# beds 54 50
# Disagree boarding
# 23325 left ward in 153.9 minutes.
# 88587 left ward in 6.3 minutes.
# 4665 arriving at ICU at 1902.0
# beds 54 51
# Became false! False 54
# Agreed not boarding
# 60554 arriving at ICU at 1910.0
# beds 53 51
# Disagree boarding
# 16691 arriving at ICU at 1918.0
# beds 55 52
# Became false! False 55
# Agreed not boarding
# 59555 arriving at ICU at 1923.0
# beds 53 52
# Became false! False 53
# Agreed not boarding
# 60554 left ward in 21.7 minutes.
# 18281 arriving at ICU at 1938.0
# beds 52 52
# Became false! False 52
# 52
# Disagree not boarding, boarding
# 59555 left ward in 24.8 minutes.
# 12089 arriving at ICU at 1952.0
# beds 53 51
# Disagree boarding
# 4665 left ward in 50.5 minutes.
# 76282 left ward in 155.3 minutes.
# 31760 left ward in 83.0 minutes.
# 84450 arriving at ICU at 1968.0
# beds 55 52
# Disagree boarding
# 25538 arriving at ICU at 1974.0
# beds 53 53
# Became false! False 53
# 53
# Disagree not boarding, boarding
# 92612 arriving at ICU at 1993.0
# beds 55 52
# Disagree boarding
# 4843 left ward in 154.6 minutes.
# 41565 arriving at ICU at 2007.0
# beds 56 54
# Became false! False 56
# Agreed not boarding
# 8061 left ward in 354.4 minutes.
# 3400 arriving at ICU at 2018.0
# beds 55 54
# Agreed boarding
# 3400 left ward in 1.3 minutes.
# 84450 left ward in 53.5 minutes.
# 1357 arriving at ICU at 2028.0
# beds 58 54
# Became false! False 58
# Agreed not boarding
# 92612 left ward in 39.2 minutes.
# 11997 arriving at ICU at 2037.0
# beds 55 54
# Became false! False 55
# Agreed not boarding
# 25874 left ward in 215.7 minutes.
# 25538 left ward in 71.0 minutes.
# 29544 arriving at ICU at 2055.0
# beds 58 55
# Disagree boarding
# 3064 arriving at ICU at 2061.0
# beds 59 56
# Disagree boarding
# 57592 arriving at ICU at 2067.0
# beds 59 57
# Became false! False 59
# Agreed not boarding
# 1357 left ward in 43.7 minutes.
# 18281 left ward in 135.7 minutes.
# 3064 left ward in 16.9 minutes.
# 48420 arriving at ICU at 2083.0
# beds 59 58
# Disagree boarding
# 93114 arriving at ICU at 2093.0
# beds 60 59
# Disagree boarding
# 48420 left ward in 16.2 minutes.
# 72666 arriving at ICU at 2100.0
# beds 61 60
# Became false! False 61
# Agreed not boarding
# 89329 arriving at ICU at 2108.0
# beds 61 60
# Became false! False 61
# 61
# Disagree not boarding, boarding
# 57592 left ward in 43.9 minutes.
# 17089 arriving at ICU at 2126.0
# beds 62 59
# Became false! False 62
# Agreed not boarding
# 72666 left ward in 28.2 minutes.
# 89329 left ward in 24.3 minutes.
# 17671 arriving at ICU at 2139.0
# beds 65 60
# Disagree boarding
# 29544 left ward in 86.2 minutes.
# 59067 arriving at ICU at 2154.0
# beds 62 61
# Disagree boarding
# 93114 left ward in 72.1 minutes.
# 31941 arriving at ICU at 2172.0
# beds 65 62
# Disagree boarding
# 12089 left ward in 236.3 minutes.
# 11997 left ward in 151.9 minutes.
# 10246 arriving at ICU at 2190.0
# beds 66 63
# Disagree boarding
# 17671 left ward in 61.3 minutes.
# 6865 arriving at ICU at 2201.0
# beds 66 64
# Disagree boarding
# 16468 arriving at ICU at 2206.0
# beds 65 65
# Became false! False 65
# 65
# Disagree not boarding, boarding
# 62438 arriving at ICU at 2214.0
# beds 64 64
# Agreed boarding
# 65033 arriving at ICU at 2224.0
# beds 68 64
# Became false! False 68
# Agreed not boarding
# 18257 arriving at ICU at 2230.0
# beds 75 64
# Became false! False 75
# Agreed not boarding
# 41565 left ward in 227.3 minutes.
# 6865 left ward in 33.4 minutes.
# 16468 left ward in 32.2 minutes.
# 31941 left ward in 70.4 minutes.
# 65033 left ward in 21.5 minutes.
# 30601 arriving at ICU at 2246.0
# beds 68 65
# Disagree boarding
# 96197 arriving at ICU at 2264.0
# beds 73 66
# Disagree boarding
# 84168 arriving at ICU at 2269.0
# beds 68 67
# Became false! False 68
# Agreed not boarding
# 96197 left ward in 15.2 minutes.
# 18257 left ward in 51.3 minutes.
# 62438 left ward in 68.7 minutes.
# 26274 arriving at ICU at 2287.0
# beds 69 67
# Disagree boarding
# 8213 arriving at ICU at 2296.0
# beds 71 68
# Disagree boarding
# 45783 arriving at ICU at 2312.0
# beds 70 69
# Became false! False 70
# 70
# Disagree not boarding, boarding
# 17089 left ward in 193.2 minutes.
# 45783 left ward in 14.9 minutes.
# 29804 arriving at ICU at 2331.0
# beds 72 69
# Became false! False 72
# Agreed not boarding
# 1901 arriving at ICU at 2339.0
# beds 69 69
# Agreed boarding
# 6572 arriving at ICU at 2353.0
# beds 70 69
# Agreed boarding
# 30601 left ward in 109.2 minutes.
# 1901 left ward in 23.7 minutes.
# 16691 left ward in 446.3 minutes.
# 6572 left ward in 18.2 minutes.
# 29804 left ward in 40.4 minutes.
# 23744 arriving at ICU at 2373.0
# beds 72 69
# Became false! False 72
# Agreed not boarding
# 59067 left ward in 224.8 minutes.
# 10246 left ward in 193.3 minutes.
# 26274 left ward in 96.4 minutes.
# 63226 arriving at ICU at 2390.0
# beds 73 69
# Became false! False 73
# 73
# Disagree not boarding, boarding
# 24172 arriving at ICU at 2407.0
# beds 70 68
# Became false! False 70
# Agreed not boarding
# 1088 arriving at ICU at 2425.0
# beds 70 68
# Became false! False 70
# Agreed not boarding
# 63226 left ward in 35.8 minutes.
# 79671 left ward in 563.6 minutes.
# 49102 arriving at ICU at 2442.0
# beds 72 70
# Disagree boarding
# 66930 arriving at ICU at 2447.0
# beds 73 71
# Disagree boarding
# 66930 left ward in 13.0 minutes.
# 8213 left ward in 164.8 minutes.
# 49102 left ward in 19.5 minutes.
# 23744 left ward in 91.4 minutes.
# 96445 arriving at ICU at 2465.0
# beds 77 72
# Became false! False 77
# Agreed not boarding
# 53466 arriving at ICU at 2480.0
# beds 74 72
# Became false! False 74
# Agreed not boarding
# 50832 arriving at ICU at 2489.0
# beds 81 72
# Became false! False 81
# Agreed not boarding
# 22987 arriving at ICU at 2496.0
# beds 73 72
# Became false! False 73
# Agreed not boarding
# 62190 arriving at ICU at 2507.0
# beds 73 72
# Disagree boarding
# 96445 left ward in 42.5 minutes.
# 53466 left ward in 28.7 minutes.
# 24172 left ward in 102.9 minutes.
# 22987 left ward in 21.3 minutes.
# 27800 arriving at ICU at 2521.0
# beds 73 73
# Became false! False 73
# 73
# Disagree not boarding, boarding
# 60763 arriving at ICU at 2528.0
# beds 74 72
# Became false! False 74
# 74
# Disagree not boarding, boarding
# 60763 left ward in 0.1 minutes.
# 50596 arriving at ICU at 2533.0
# beds 74 72
# Disagree boarding
# 50832 left ward in 47.1 minutes.
# 59469 arriving at ICU at 2545.0
# beds 74 73
# Became false! False 74
# Agreed not boarding
# 62190 left ward in 42.9 minutes.
# 50596 left ward in 20.9 minutes.
# 1900 arriving at ICU at 2558.0
# beds 79 73
# Disagree boarding
# 7930 arriving at ICU at 2575.0
# beds 75 74
# Became false! False 75
# Agreed not boarding
# 27636 arriving at ICU at 2586.0
# beds 76 74
# Disagree boarding
# 28690 arriving at ICU at 2597.0
# beds 79 75
# Became false! False 79
# Agreed not boarding
# 19911 left ward in 2197.7 minutes.
# 27636 left ward in 18.0 minutes.
# 1088 left ward in 185.0 minutes.
# 7930 left ward in 36.9 minutes.
# 18725 arriving at ICU at 2616.0
# beds 78 76
# Disagree boarding
# 30365 arriving at ICU at 2621.0
# beds 79 77
# Became false! False 79
# Agreed not boarding
# 27800 left ward in 103.3 minutes.
# 43969 arriving at ICU at 2639.0
# beds 78 78
# Agreed boarding
# 1900 left ward in 86.6 minutes.
# 59469 left ward in 101.9 minutes.
# 30245 arriving at ICU at 2654.0
# beds 78 78
# Agreed boarding
# 84168 left ward in 390.9 minutes.
# 74740 arriving at ICU at 2662.0
# beds 81 78
# Became false! False 81
# Agreed not boarding
# 28690 left ward in 71.4 minutes.
# 18725 left ward in 53.0 minutes.
# 74740 left ward in 7.8 minutes.
# 43969 left ward in 35.8 minutes.
# 57654 arriving at ICU at 2676.0
# beds 79 78
# Became false! False 79
# 79
# Disagree not boarding, boarding
# 30245 left ward in 23.2 minutes.
# 546 arriving at ICU at 2689.0
# beds 78 77
# Became false! False 78
# Agreed not boarding
# 57654 left ward in 13.4 minutes.
# 73884 arriving at ICU at 2695.0
# beds 84 78
# Became false! False 84
# Agreed not boarding
# 50832 arriving at ICU at 2703.0
# beds 87 78
# Became false! False 87
# Agreed not boarding
# 546 left ward in 23.4 minutes.
# 73884 left ward in 18.9 minutes.
# 14994 arriving at ICU at 2715.0
# beds 80 78
# Agreed boarding
# 13308 arriving at ICU at 2733.0
# beds 80 78
# Disagree boarding
# 19580 arriving at ICU at 2738.0
# beds 82 79
# Became false! False 82
# Agreed not boarding
# 88660 arriving at ICU at 2748.0
# beds 82 79
# Disagree boarding
# 50832 left ward in 47.1 minutes.
# 14994 left ward in 37.5 minutes.
# 58514 arriving at ICU at 2758.0
# beds 83 80
# Became false! False 83
# Agreed not boarding
# 25446 arriving at ICU at 2764.0
# beds 81 80
# Became false! False 81
# 81
# Disagree not boarding, boarding
# 19580 left ward in 38.2 minutes.
# 88660 left ward in 29.7 minutes.
# 67687 arriving at ICU at 2779.0
# beds 81 79
# Disagree boarding
# 30365 left ward in 161.5 minutes.
# 18140 arriving at ICU at 2788.0
# beds 82 80
# Became false! False 82
# Agreed not boarding
# 7681 arriving at ICU at 2793.0
# beds 81 80
# Became false! False 81
# Agreed not boarding
# 58514 left ward in 45.4 minutes.
# 78782 arriving at ICU at 2805.0
# beds 82 80
# Became false! False 82
# Agreed not boarding
# 67687 left ward in 29.3 minutes.
# 18140 left ward in 23.3 minutes.
# 7138 arriving at ICU at 2814.0
# beds 81 80
# Disagree boarding
# 8985 arriving at ICU at 2821.0
# beds 82 81
# Became false! False 82
# Agreed not boarding
# 8985 left ward in 9.2 minutes.
# 94229 arriving at ICU at 2834.0
# beds 83 81
# Became false! False 83
# Agreed not boarding
# 25446 left ward in 70.2 minutes.
# 7138 left ward in 24.5 minutes.
# 7681 left ward in 46.9 minutes.
# 45531 arriving at ICU at 2842.0
# beds 82 82
# Became false! False 82
# 82
# Disagree not boarding, boarding
# 13308 left ward in 112.6 minutes.
# 78782 left ward in 42.3 minutes.
# 78705 arriving at ICU at 2856.0
# beds 82 81
# Disagree boarding
# 45531 left ward in 26.3 minutes.
# 23249 arriving at ICU at 2870.0
# beds 84 83
# Disagree boarding
# 16640 arriving at ICU at 2887.0
# beds 88 84
# Disagree boarding
# 14411 arriving at ICU at 2893.0
# beds 90 85
# Disagree boarding
# 31369 arriving at ICU at 2900.0
# beds 90 86
# Disagree boarding
# 55673 arriving at ICU at 2913.0
# beds 94 87
# Disagree boarding
# 18975 arriving at ICU at 2931.0
# beds 89 88
# Agreed boarding
# 19126 arriving at ICU at 2941.0
# beds 90 88
# Agreed boarding
# 14411 left ward in 49.4 minutes.
# 55673 left ward in 36.7 minutes.
# 31369 left ward in 50.1 minutes.
# 94229 left ward in 118.8 minutes.
# 14766 arriving at ICU at 2957.0
# beds 90 88
# Became false! False 90
# Agreed not boarding
# 23249 left ward in 93.1 minutes.
# 74376 arriving at ICU at 2966.0
# beds 89 88
# Disagree boarding
# 14766 left ward in 19.4 minutes.
# 82188 arriving at ICU at 2982.0
# beds 93 89
# Disagree boarding
# 78705 left ward in 127.7 minutes.
# 77948 arriving at ICU at 2991.0
# beds 93 90
# Became false! False 93
# Agreed not boarding
# 16640 left ward in 116.9 minutes.
# 82188 left ward in 24.4 minutes.
# 65759 arriving at ICU at 3007.0
# beds 91 90
# Became false! False 91
# Agreed not boarding
# 74376 left ward in 42.6 minutes.
# 54043 arriving at ICU at 3015.0
# beds 91 90
# Agreed boarding
# 18975 left ward in 91.0 minutes.
# 7029 arriving at ICU at 3028.0
# beds 92 90
# Disagree boarding
# 9672 arriving at ICU at 3040.0
# beds 91 91
# Became false! False 91
# 91
# Disagree not boarding, boarding
# 7029 left ward in 19.3 minutes.
# 15051 arriving at ICU at 3052.0
# beds 94 90
# Became false! False 94
# Agreed not boarding
# 1000 arriving at ICU at 3058.0
# beds 92 90
# Became false! False 92
# Agreed not boarding
# 11892 arriving at ICU at 3070.0
# beds 92 90
# Became false! False 92
# 92
# Disagree not boarding, boarding
# 80237 arriving at ICU at 3079.0
# beds 92 89
# Became false! False 92
# Agreed not boarding
# 19126 left ward in 150.9 minutes.
# 44059 arriving at ICU at 3093.0
# beds 92 89
# Disagree boarding
# 27563 arriving at ICU at 3100.0
# beds 90 90
# Became false! False 90
# 90
# Disagree not boarding, boarding
# 15051 left ward in 56.0 minutes.
# 65759 left ward in 102.1 minutes.
# 26804 arriving at ICU at 3115.0
# beds 90 89
# Disagree boarding
# 27563 left ward in 19.0 minutes.
# 84036 arriving at ICU at 3125.0
# beds 94 91
# Disagree boarding
# 78647 arriving at ICU at 3131.0
# beds 94 92
# Became false! False 94
# Agreed not boarding
# 9672 left ward in 97.0 minutes.
# 82935 arriving at ICU at 3137.0
# beds 96 93
# Became false! False 96
# Agreed not boarding
# 80237 left ward in 60.8 minutes.
# 2332 arriving at ICU at 3148.0
# beds 95 93
# Disagree boarding
# 82935 left ward in 13.6 minutes.
# 2744 arriving at ICU at 3162.0
# beds 95 94
# Became false! False 95
# 95
# Disagree not boarding, boarding
# 84036 left ward in 44.4 minutes.
# 78647 left ward in 39.9 minutes.
# 32440 arriving at ICU at 3171.0
# beds 97 93
# Became false! False 97
# Agreed not boarding
# 56378 arriving at ICU at 3179.0
# beds 94 93
# Became false! False 94
# 94
# Disagree not boarding, boarding
# 3078 arriving at ICU at 3197.0
# beds 95 92
# Disagree boarding
# 41653 arriving at ICU at 3215.0
# beds 94 93
# Agreed boarding
# 31637 arriving at ICU at 3227.0
# beds 94 93
# Disagree boarding
# 56378 left ward in 51.0 minutes.
# 77948 left ward in 239.7 minutes.
# 47532 arriving at ICU at 3234.0
# beds 99 95
# Became false! False 99
# Agreed not boarding
# 2744 left ward in 86.5 minutes.
# 87896 arriving at ICU at 3253.0
# beds 99 96
# Became false! False 99
# Agreed not boarding
# 68736 arriving at ICU at 3271.0
# beds 97 96
# Became false! False 97
# Agreed not boarding
# 31637 left ward in 45.2 minutes.
# 2332 left ward in 125.6 minutes.
# 72083 arriving at ICU at 3276.0
# beds 97 96
# Became false! False 97
# 97
# Disagree not boarding, boarding
# 41653 left ward in 68.5 minutes.
# 87896 left ward in 36.9 minutes.
# 27355 arriving at ICU at 3292.0
# beds 95 95
# Became false! False 95
# 95
# Disagree not boarding, boarding
# 68736 left ward in 24.5 minutes.
# 11892 left ward in 230.7 minutes.
# 2375 arriving at ICU at 3302.0
# beds 95 95
# Agreed boarding
# 26804 left ward in 188.2 minutes.
# 2375 left ward in 2.6 minutes.
# 32440 left ward in 134.9 minutes.
# 71190 arriving at ICU at 3308.0
# beds 98 95
# Became false! False 98
# Agreed not boarding
# 3078 left ward in 112.1 minutes.
# 75795 arriving at ICU at 3321.0
# beds 97 95
# Disagree boarding
# 72083 left ward in 48.7 minutes.
# 47532 left ward in 99.1 minutes.
# 16877 arriving at ICU at 3338.0
# beds 98 97
# Agreed boarding
# 75795 left ward in 18.5 minutes.
# 27355 left ward in 48.9 minutes.
# 30800 arriving at ICU at 3351.0
# beds 98 98
# Agreed boarding
# 30800 left ward in 9.0 minutes.
# 4489 arriving at ICU at 3366.0
# beds 99 98
# Became false! False 99
# Agreed not boarding
# 81050 arriving at ICU at 3374.0
# beds 100 98
# Disagree boarding
# 54043 left ward in 365.8 minutes.
# 4489 left ward in 16.4 minutes.
# 81050 left ward in 14.1 minutes.
# 61455 arriving at ICU at 3391.0
# beds 100 99
# Became false! False 100
# Agreed not boarding
# 71190 left ward in 90.4 minutes.
# 12531 arriving at ICU at 3402.0
# beds 102 99
# Disagree boarding
# 16877 left ward in 71.1 minutes.
# 61455 left ward in 30.4 minutes.
# 19036 arriving at ICU at 3422.0
# beds 100 100
# Became false! False 100
# 100
# Disagree not boarding, boarding
# 44059 left ward in 339.5 minutes.
# 89849 arriving at ICU at 3442.0
# beds 99 99
# Became false! False 99
# 99
# Disagree not boarding, boarding
# 19036 left ward in 28.5 minutes.
# 7900 arriving at ICU at 3452.0
# beds 100 99
# Disagree boarding
# 9871 arriving at ICU at 3463.0
# beds 103 100
# Disagree boarding
# 7900 left ward in 13.5 minutes.
# 72660 arriving at ICU at 3468.0
# beds 101 101
# Agreed boarding
# 72660 left ward in 0.2 minutes.
# 9871 left ward in 17.7 minutes.
# 21651 arriving at ICU at 3487.0
# beds 102 101
# Became false! False 102
# Agreed not boarding
# 5542 arriving at ICU at 3500.0
# beds 101 101
# Agreed boarding
# 62431 arriving at ICU at 3516.0
# beds 103 101
# Became false! False 103
# Agreed not boarding
# 12017 arriving at ICU at 3529.0
# beds 105 101
# Disagree boarding
# 21651 left ward in 45.3 minutes.
# 89849 left ward in 91.2 minutes.
# 14197 arriving at ICU at 3539.0
# beds 105 103
# Disagree boarding
# 62431 left ward in 23.0 minutes.
# 45524 arriving at ICU at 3547.0
# beds 104 104
# Agreed boarding
# 63116 arriving at ICU at 3566.0
# beds 109 104
# Became false! False 109
# Agreed not boarding
# 9296 arriving at ICU at 3574.0
# beds 106 104
# Became false! False 106
# Agreed not boarding
# 45524 left ward in 33.9 minutes.
# 14197 left ward in 43.4 minutes.
# 48380 arriving at ICU at 3592.0
# beds 113 104
# Disagree boarding
# 12531 left ward in 192.5 minutes.
# 77213 arriving at ICU at 3600.0
# beds 107 105
# Disagree boarding
# 63116 left ward in 44.7 minutes.
# 11395 arriving at ICU at 3613.0
# beds 107 106
# Disagree boarding
# 77213 left ward in 20.2 minutes.
# 20542 arriving at ICU at 3622.0
# beds 111 107
# Became false! False 111
# 111
# Disagree not boarding, boarding
# 27427 arriving at ICU at 3634.0
# beds 108 106
# Disagree boarding
# 63745 arriving at ICU at 3640.0
# beds 108 107
# Became false! False 108
# 108
# Disagree not boarding, boarding
# 9296 left ward in 68.4 minutes.
# 20542 left ward in 25.5 minutes.
# 52254 arriving at ICU at 3649.0
# beds 109 107
# Became false! False 109
# Agreed not boarding
# 27427 left ward in 19.3 minutes.
# 11395 left ward in 42.1 minutes.
# 48380 left ward in 67.6 minutes.
# 5542 left ward in 160.5 minutes.
# 93315 arriving at ICU at 3666.0
# beds 110 107
# Disagree boarding
# 49133 arriving at ICU at 3671.0
# beds 109 108
# Became false! False 109
# 109
# Disagree not boarding, boarding
# 16349 arriving at ICU at 3678.0
# beds 107 107
# Became false! False 107
# 107
# Disagree not boarding, boarding
# 63745 left ward in 55.8 minutes.
# 82445 arriving at ICU at 3698.0
# beds 112 107
# Disagree boarding
# 52254 left ward in 54.1 minutes.
# 49133 left ward in 38.2 minutes.
# 26967 arriving at ICU at 3713.0
# beds 110 109
# Became false! False 110
# Agreed not boarding
# 82445 left ward in 17.0 minutes.
# 16349 left ward in 37.8 minutes.
# 93315 left ward in 50.8 minutes.
# 88911 arriving at ICU at 3730.0
# beds 111 110
# Became false! False 111
# Agreed not boarding
# 3813 arriving at ICU at 3740.0
# beds 111 110
# Disagree boarding
# 26967 left ward in 36.7 minutes.
# 51059 arriving at ICU at 3750.0
# beds 114 111
# Became false! False 114
# Agreed not boarding
# 12017 left ward in 227.8 minutes.
# 62571 arriving at ICU at 3760.0
# beds 114 111
# Disagree boarding
# 88911 left ward in 41.4 minutes.
# 31614 arriving at ICU at 3778.0
# beds 112 112
# Agreed boarding
# 3813 left ward in 42.4 minutes.
# 62571 left ward in 22.9 minutes.
# 51059 left ward in 32.9 minutes.
# 80473 arriving at ICU at 3783.0
# beds 115 112
# Disagree boarding
# 12094 arriving at ICU at 3792.0
# beds 115 113
# Disagree boarding
# 55337 arriving at ICU at 3807.0
# beds 117 114
# Became false! False 117
# Agreed not boarding
# 80473 left ward in 29.6 minutes.
# 31614 left ward in 35.5 minutes.
# 12089 arriving at ICU at 3825.0
# beds 116 114
# Disagree boarding
# 19441 arriving at ICU at 3838.0
# beds 117 115
# Disagree boarding
# 11995 arriving at ICU at 3849.0
# beds 121 116
# Disagree boarding
# 19441 left ward in 20.8 minutes.
# 88518 arriving at ICU at 3868.0
# beds 119 117
# Became false! False 119
# Agreed not boarding
# 28808 arriving at ICU at 3881.0
# beds 119 117
# Agreed boarding
# 88518 left ward in 15.3 minutes.
# 8662 arriving at ICU at 3898.0
# beds 120 117
# Became false! False 120
# Agreed not boarding
# 20009 arriving at ICU at 3906.0
# beds 117 117
# Became false! False 117
# 117
# Disagree not boarding, boarding
# 12094 left ward in 117.9 minutes.
# 13253 arriving at ICU at 3911.0
# beds 127 116
# Disagree boarding
# 50710 arriving at ICU at 3925.0
# beds 118 117
# Became false! False 118
# 118
# Disagree not boarding, boarding
# 20009 left ward in 23.5 minutes.
# 28808 left ward in 50.7 minutes.
# 13253 left ward in 21.4 minutes.
# 1000 left ward in 880.8 minutes.
# 72538 arriving at ICU at 3945.0
# beds 119 117
# Disagree boarding
# 8662 left ward in 64.2 minutes.
# 32526 arriving at ICU at 3963.0
# beds 120 118
# Disagree boarding
# 14818 arriving at ICU at 3982.0
# beds 123 119
# Disagree boarding
# 11995 left ward in 138.0 minutes.
# 7260 arriving at ICU at 3991.0
# beds 127 120
# Became false! False 127
# Agreed not boarding
# 55337 left ward in 185.2 minutes.
# 48344 arriving at ICU at 3998.0
# beds 124 120
# Disagree boarding
# 50710 left ward in 82.9 minutes.
# 58825 arriving at ICU at 4009.0
# beds 127 122
# Became false! False 127
# Agreed not boarding
# 48851 arriving at ICU at 4026.0
# beds 122 122
# Became false! False 122
# 122
# Disagree not boarding, boarding
# 7260 left ward in 35.3 minutes.
# 32526 left ward in 67.3 minutes.
# 64377 arriving at ICU at 4032.0
# beds 126 121
# Disagree boarding
# 24853 arriving at ICU at 4042.0
# beds 123 122
# Became false! False 123
# Agreed not boarding
# 48344 left ward in 48.1 minutes.
# 72538 left ward in 103.1 minutes.
# 31692 arriving at ICU at 4051.0
# beds 123 122
# Agreed boarding
# 48851 left ward in 27.3 minutes.
# 6346 arriving at ICU at 4056.0
# beds 125 123
# Disagree boarding
# 12089 left ward in 236.3 minutes.
# 24853 left ward in 29.9 minutes.
# 31692 left ward in 21.0 minutes.
# 80560 arriving at ICU at 4073.0
# beds 128 124
# Disagree boarding
# 58825 left ward in 66.2 minutes.
# 64377 left ward in 54.7 minutes.
# 1120 arriving at ICU at 4091.0
# beds 128 125
# Became false! False 128
# Agreed not boarding
# 14818 left ward in 119.4 minutes.
# 80560 left ward in 28.8 minutes.
# 61606 arriving at ICU at 4111.0
# beds 131 125
# Became false! False 131
# Agreed not boarding
# 1120 left ward in 38.9 minutes.
# 97716 arriving at ICU at 4130.0
# beds 128 125
# Became false! False 128
# Agreed not boarding
# 64736 arriving at ICU at 4137.0
# beds 127 125
# Disagree boarding
# 27655 arriving at ICU at 4144.0
# beds 128 126
# Became false! False 128
# Agreed not boarding
# 75993 arriving at ICU at 4159.0
# beds 128 126
# Became false! False 128
# Agreed not boarding
# 76134 arriving at ICU at 4171.0
# beds 136 126
# Agreed boarding
# 27655 left ward in 31.4 minutes.
# 1357 arriving at ICU at 4181.0
# beds 130 126
# Became false! False 130
# Agreed not boarding
# 3987 arriving at ICU at 4189.0
# beds 127 126
# Disagree boarding
# 6346 left ward in 141.0 minutes.
# 88009 arriving at ICU at 4199.0
# beds 130 127
# Disagree boarding
# 88009 left ward in 1.0 minutes.
# 97716 left ward in 72.1 minutes.
# 61606 left ward in 98.6 minutes.
# 75993 left ward in 51.3 minutes.
# 47589 arriving at ICU at 4211.0
# beds 131 128
# Became false! False 131
# Agreed not boarding
# 1357 left ward in 43.7 minutes.
# 3987 left ward in 41.7 minutes.
# 93052 arriving at ICU at 4231.0
# beds 131 128
# Disagree boarding
# 76134 left ward in 71.6 minutes.
# 19769 arriving at ICU at 4245.0
# beds 132 129
# Disagree boarding
# 63116 arriving at ICU at 4253.0
# beds 135 130
# Became false! False 135
# Agreed not boarding
# 19769 left ward in 19.3 minutes.
# 67442 arriving at ICU at 4269.0
# beds 136 130
# Became false! False 136
# Agreed not boarding
# 93052 left ward in 44.5 minutes.
# 64736 left ward in 146.9 minutes.
# 17735 arriving at ICU at 4284.0
# beds 133 130
# Became false! False 133
# Agreed not boarding
# 92050 arriving at ICU at 4291.0
# beds 133 130
# Became false! False 133
# Agreed not boarding
# 67442 left ward in 22.6 minutes.
# 63116 left ward in 44.7 minutes.
# 10783 arriving at ICU at 4310.0
# beds 132 130
# Disagree boarding
# 9999 arriving at ICU at 4320.0
# beds 135 131
# Disagree boarding
# 92050 left ward in 31.0 minutes.
# 31234 arriving at ICU at 4325.0
# beds 136 132
# Became false! False 136
# Agreed not boarding
# 17735 left ward in 48.2 minutes.
# 25446 arriving at ICU at 4336.0
# beds 133 132
# Became false! False 133
# 133
# Disagree not boarding, boarding
# 9999 left ward in 26.7 minutes.
# 42189 arriving at ICU at 4355.0
# beds 134 131
# Became false! False 134
# Agreed not boarding
# 31234 left ward in 31.3 minutes.
# 86866 arriving at ICU at 4362.0
# beds 135 131
# Disagree boarding
# 84463 arriving at ICU at 4376.0
# beds 136 132
# Disagree boarding
# 97229 arriving at ICU at 4390.0
# beds 134 133
# Became false! False 134
# Agreed not boarding
# 10783 left ward in 81.7 minutes.
# 52779 arriving at ICU at 4400.0
# beds 135 133
# Became false! False 135
# Agreed not boarding
# 25446 left ward in 70.2 minutes.
# 84463 left ward in 30.8 minutes.
# 96814 arriving at ICU at 4412.0
# beds 138 134
# Became false! False 138
# Agreed not boarding
# 58144 arriving at ICU at 4428.0
# beds 138 134
# Became false! False 138
# Agreed not boarding
# 30067 arriving at ICU at 4440.0
# beds 134 134
# Became false! False 134
# 134
# Disagree not boarding, boarding
# 28093 arriving at ICU at 4448.0
# beds 140 133
# Became false! False 140
# Agreed not boarding
# 42189 left ward in 99.6 minutes.
# 58144 left ward in 26.6 minutes.
# 96814 left ward in 46.7 minutes.
# 97229 left ward in 70.1 minutes.
# 66213 arriving at ICU at 4467.0
# beds 135 133
# Became false! False 135
# 135
# Disagree not boarding, boarding
# 86810 arriving at ICU at 4472.0
# beds 132 132
# Agreed boarding
# 28093 left ward in 24.7 minutes.
# 86866 left ward in 110.9 minutes.
# 48100 arriving at ICU at 4480.0
# beds 133 132
# Disagree boarding
# 52779 left ward in 83.0 minutes.
# 66213 left ward in 17.3 minutes.
# 10000 arriving at ICU at 4487.0
# beds 136 134
# Became false! False 136
# 136
# Disagree not boarding, boarding
# 86810 left ward in 19.4 minutes.
# 20481 arriving at ICU at 4492.0
# beds 134 133
# Disagree boarding
# 50547 arriving at ICU at 4503.0
# beds 134 134
# Agreed boarding
# 47589 left ward in 307.5 minutes.
# 10000 left ward in 31.8 minutes.
# 64407 arriving at ICU at 4519.0
# beds 138 135
# Became false! False 138
# Agreed not boarding
# 48100 left ward in 47.4 minutes.
# 50547 left ward in 29.8 minutes.
# 30067 left ward in 97.7 minutes.
# 85490 arriving at ICU at 4538.0
# beds 138 136
# Agreed boarding
# 20481 left ward in 48.4 minutes.
# 7423 arriving at ICU at 4547.0
# beds 137 136
# Became false! False 137
# Agreed not boarding
# 29682 arriving at ICU at 4552.0
# beds 137 136
# Disagree boarding
# 15251 arriving at ICU at 4563.0
# beds 141 137
# Became false! False 141
# Agreed not boarding
# 49382 arriving at ICU at 4571.0
# beds 141 137
# Became false! False 141
# Agreed not boarding
# 7423 left ward in 31.4 minutes.
# 5981 arriving at ICU at 4589.0
# beds 139 137
# Became false! False 139
# Agreed not boarding
# 15251 left ward in 30.2 minutes.
# 49382 left ward in 24.8 minutes.
# 19338 arriving at ICU at 4608.0
# beds 140 137
# Disagree boarding
# 5981 left ward in 29.7 minutes.
# 745 arriving at ICU at 4627.0
# beds 139 138
# Agreed boarding
# 4973 arriving at ICU at 4643.0
# beds 141 138
# Disagree boarding
# 19338 left ward in 36.1 minutes.
# 85490 left ward in 109.5 minutes.
# 29682 left ward in 96.7 minutes.
# 745 left ward in 27.8 minutes.
# 21414 arriving at ICU at 4662.0
# beds 144 139
# Became false! False 144
# Agreed not boarding
# 26291 arriving at ICU at 4667.0
# beds 148 139
# Disagree boarding
# 92695 arriving at ICU at 4677.0
# beds 143 140
# Became false! False 143
# Agreed not boarding
# 700 arriving at ICU at 4689.0
# beds 140 140
# Became false! False 140
# 140
# Disagree not boarding, boarding
# 26291 left ward in 27.5 minutes.
# 85195 arriving at ICU at 4696.0
# beds 139 139
# Became false! False 139
# 139
# Disagree not boarding, boarding
# 4973 left ward in 62.6 minutes.
# 18738 arriving at ICU at 4707.0
# beds 140 138
# Disagree boarding
# 21414 left ward in 53.7 minutes.
# 62594 arriving at ICU at 4716.0
# beds 142 139
# Disagree boarding
# 700 left ward in 35.5 minutes.
# 64407 left ward in 211.8 minutes.
# 81662 arriving at ICU at 4731.0
# beds 142 141
# Became false! False 142
# Agreed not boarding
# 92695 left ward in 65.0 minutes.
# 23749 arriving at ICU at 4749.0
# beds 142 141
# Became false! False 142
# Agreed not boarding
# 85195 left ward in 61.1 minutes.
# 81662 left ward in 26.8 minutes.
# 2786 arriving at ICU at 4763.0
# beds 142 142
# Agreed boarding
# 62594 left ward in 48.0 minutes.
# 77553 arriving at ICU at 4782.0
# beds 145 142
# Became false! False 145
# Agreed not boarding
# 52622 arriving at ICU at 4790.0
# beds 144 142
# Disagree boarding
# 2786 left ward in 40.0 minutes.
# 51529 arriving at ICU at 4809.0
# beds 146 143
# Disagree boarding
# 77553 left ward in 28.8 minutes.
# 20125 arriving at ICU at 4827.0
# beds 146 144
# Became false! False 146
# Agreed not boarding
# 52622 left ward in 43.7 minutes.
# 46510 arriving at ICU at 4840.0
# beds 151 144
# Became false! False 151
# Agreed not boarding
# 51529 left ward in 35.1 minutes.
# 90143 arriving at ICU at 4850.0
# beds 147 144
# Disagree boarding
# 46510 left ward in 17.7 minutes.
# 29463 arriving at ICU at 4861.0
# beds 146 145
# Disagree boarding
# 23749 left ward in 113.0 minutes.
# 18738 left ward in 160.1 minutes.
# 362 arriving at ICU at 4869.0
# beds 151 146
# Became false! False 151
# Agreed not boarding
# 5808 arriving at ICU at 4879.0
# beds 148 146
# Disagree boarding
# 5289 arriving at ICU at 4889.0
# beds 148 147
# Disagree boarding
# 29463 left ward in 30.9 minutes.
# 362 left ward in 22.9 minutes.
# 3700 arriving at ICU at 4903.0
# beds 148 148
# Agreed boarding
# 90143 left ward in 57.3 minutes.
# 5289 left ward in 18.3 minutes.
# 75688 arriving at ICU at 4910.0
# beds 151 148
# Became false! False 151
# Agreed not boarding
# 5808 left ward in 32.7 minutes.
# 16568 arriving at ICU at 4915.0
# beds 149 148
# Became false! False 149
# 149
# Disagree not boarding, boarding
# 41716 arriving at ICU at 4927.0
# beds 148 147
# Disagree boarding
# 16013 arriving at ICU at 4938.0
# beds 152 148
# Became false! False 152
# Agreed not boarding
# 3700 left ward in 42.3 minutes.
# 41716 left ward in 23.4 minutes.
# 14197 arriving at ICU at 4954.0
# beds 150 148
# Disagree boarding
# 75688 left ward in 48.8 minutes.
# 65268 arriving at ICU at 4966.0
# beds 150 149
# Agreed boarding
# 9778 arriving at ICU at 4978.0
# beds 150 149
# Disagree boarding
# 1701 arriving at ICU at 4993.0
# beds 151 150
# Became false! False 151
# Agreed not boarding
# 16013 left ward in 55.4 minutes.
# 14197 left ward in 43.4 minutes.
# 16568 left ward in 91.7 minutes.
# 70871 arriving at ICU at 5009.0
# beds 153 151
# Agreed boarding
# 20125 left ward in 185.0 minutes.
# 12166 arriving at ICU at 5022.0
# beds 153 151
# Became false! False 153
# Agreed not boarding
# 9266 arriving at ICU at 5033.0
# beds 152 151
# Disagree boarding
# 1701 left ward in 50.1 minutes.
# 1893 arriving at ICU at 5050.0
# beds 154 152
# Agreed boarding
# 70871 left ward in 48.5 minutes.
# 59443 arriving at ICU at 5065.0
# beds 154 152
# Disagree boarding
# 9266 left ward in 36.5 minutes.
# 11425 arriving at ICU at 5071.0
# beds 158 153
# Became false! False 158
# 158
# Disagree not boarding, boarding
# 4313 arriving at ICU at 5083.0
# beds 155 152
# Became false! False 155
# Agreed not boarding
# 41547 arriving at ICU at 5092.0
# beds 153 152
# Agreed boarding
# 59443 left ward in 29.3 minutes.
# 49872 arriving at ICU at 5104.0
# beds 158 152
# Disagree boarding
# 4313 left ward in 26.3 minutes.
# 65268 left ward in 148.1 minutes.
# 32247 arriving at ICU at 5116.0
# beds 155 153
# Disagree boarding
# 9778 left ward in 140.3 minutes.
# 5957 arriving at ICU at 5124.0
# beds 155 154
# Agreed boarding
# 86323 arriving at ICU at 5143.0
# beds 156 154
# Became false! False 156
# Agreed not boarding
# 9908 arriving at ICU at 5160.0
# beds 158 154
# Disagree boarding
# 49872 left ward in 60.8 minutes.
# 12166 left ward in 147.7 minutes.
# 41547 left ward in 87.8 minutes.
# 9195 arriving at ICU at 5180.0
# beds 159 155
# Disagree boarding
# 16864 arriving at ICU at 5195.0
# beds 159 156
# Became false! False 159
# Agreed not boarding
# 9908 left ward in 35.7 minutes.
# 5957 left ward in 72.0 minutes.
# 70077 arriving at ICU at 5210.0
# beds 160 156
# Became false! False 160
# Agreed not boarding
# 16864 left ward in 18.8 minutes.
# 32247 left ward in 103.8 minutes.
# 31307 arriving at ICU at 5230.0
# beds 159 156
# Became false! False 159
# Agreed not boarding
# 1893 left ward in 182.0 minutes.
# 70077 left ward in 24.9 minutes.
# 51203 arriving at ICU at 5246.0
# beds 165 156
# Agreed boarding
# 9195 left ward in 71.6 minutes.
# 66015 arriving at ICU at 5266.0
# beds 158 156
# Became false! False 158
# Agreed not boarding
# 31307 left ward in 36.7 minutes.
# 1895 arriving at ICU at 5273.0
# beds 157 156
# Disagree boarding
# 51203 left ward in 29.9 minutes.
# 13216 arriving at ICU at 5287.0
# beds 160 157
# Became false! False 160
# Agreed not boarding
# 8228 arriving at ICU at 5296.0
# beds 159 157
# Disagree boarding
# 50093 arriving at ICU at 5303.0
# beds 170 158
# Became false! False 170
# Agreed not boarding
# 13216 left ward in 21.8 minutes.
# 12568 arriving at ICU at 5314.0
# beds 159 158
# Disagree boarding
# 8228 left ward in 27.8 minutes.
# 99183 arriving at ICU at 5325.0
# beds 160 159
# Became false! False 160
# 160
# Disagree not boarding, boarding
# 66015 left ward in 65.1 minutes.
# 99982 arriving at ICU at 5340.0
# beds 160 158
# Agreed boarding
# 50093 left ward in 41.6 minutes.
# 99183 left ward in 21.7 minutes.
# 26629 arriving at ICU at 5352.0
# beds 163 159
# Disagree boarding
# 12568 left ward in 41.0 minutes.
# 1895 left ward in 82.5 minutes.
# 86323 left ward in 213.7 minutes.
# 71274 arriving at ICU at 5363.0
# beds 166 160
# Became false! False 166
# Agreed not boarding
# 26629 left ward in 21.9 minutes.
# 30977 arriving at ICU at 5380.0
# beds 161 160
# Agreed boarding
# 71274 left ward in 19.6 minutes.
# 19392 arriving at ICU at 5385.0
# beds 164 160
# Became false! False 164
# Agreed not boarding
# 30977 left ward in 21.9 minutes.
# 20152 arriving at ICU at 5403.0
# beds 161 160
# Agreed boarding
# 43093 arriving at ICU at 5417.0
# beds 164 160
# Disagree boarding
# 19392 left ward in 34.5 minutes.
# 912 arriving at ICU at 5432.0
# beds 162 161
# Disagree boarding
# 43093 left ward in 19.2 minutes.
# 912 left ward in 11.2 minutes.
# 26648 arriving at ICU at 5446.0
# beds 165 162
# Disagree boarding
# 20152 left ward in 53.4 minutes.
# 30561 arriving at ICU at 5463.0
# beds 165 163
# Disagree boarding
# 8061 arriving at ICU at 5471.0
# beds 165 164
# Agreed boarding
# 4275 arriving at ICU at 5477.0
# beds 166 164
# Became false! False 166
# 166
# Disagree not boarding, boarding
# 11425 left ward in 411.4 minutes.
# 11811 arriving at ICU at 5486.0
# beds 165 164
# Agreed boarding
# 99982 left ward in 148.1 minutes.
# 30561 left ward in 25.9 minutes.
# 54724 arriving at ICU at 5494.0
# beds 165 164
# ...
# 24887 arriving at ICU at 19778.0
# beds 608 605
# Became false! False 608
# Agreed not boarding
# 98584 left ward in 50.2 minutes.
# 13011 left ward in 27.3 minutes.
# 65394 arriving at ICU at 19787.0
# beds 607 605
# Disagree boarding
# 24887 left ward in 25.4 minutes.
# 57751 arriving at ICU at 19804.0
# beds 608 606
# Became false! False 608
# Agreed not boarding
# 69569 arriving at ICU at 19813.0
# beds 609 606
# Disagree boarding
# 57751 left ward in 24.5 minutes.
# 65523 arriving at ICU at 19830.0
# beds 611 607
# Became false! False 611
# Agreed not boarding
# 28746 arriving at ICU at 19839.0
# beds 610 607
# Became false! False 610
# Agreed not boarding
# 71599 left ward in 162.9 minutes.
# 24656 arriving at ICU at 19849.0
# beds 612 607
# Disagree boarding
# 69569 left ward in 39.2 minutes.
# 28746 left ward in 17.9 minutes.
# 9523 arriving at ICU at 19858.0
# beds 609 608
# Became false! False 609
# Agreed not boarding
# 65523 left ward in 32.8 minutes.
# 98853 arriving at ICU at 19865.0
# beds 609 608
# Disagree boarding
# 65394 left ward in 84.8 minutes.
# 24656 left ward in 27.5 minutes.
# 12937 arriving at ICU at 19878.0
# beds 611 609
# Became false! False 611
# 611
# Disagree not boarding, boarding
# 98853 left ward in 15.3 minutes.
# 73843 left ward in 176.8 minutes.
# 94142 arriving at ICU at 19885.0
# beds 614 608
# Became false! False 614
# Agreed not boarding
# 9523 left ward in 36.4 minutes.
# 13845 arriving at ICU at 19899.0
# beds 613 608
# Became false! False 613
# Agreed not boarding
# 54923 arriving at ICU at 19905.0
# beds 609 608
# Disagree boarding
# 12937 left ward in 32.5 minutes.
# 53340 arriving at ICU at 19925.0
# beds 614 610
# Disagree boarding
# 94142 left ward in 45.2 minutes.
# 90153 arriving at ICU at 19931.0
# beds 612 611
# Became false! False 612
# Agreed not boarding
# 27729 arriving at ICU at 19940.0
# beds 612 611
# Became false! False 612
# Agreed not boarding
# 90153 left ward in 12.3 minutes.
# 4843 arriving at ICU at 19947.0
# beds 611 611
# Became false! False 611
# 611
# Disagree not boarding, boarding
# 13845 left ward in 55.7 minutes.
# 5367 arriving at ICU at 19960.0
# beds 614 610
# Became false! False 614
# Agreed not boarding
# 53340 left ward in 35.5 minutes.
# 17617 arriving at ICU at 19970.0
# beds 613 610
# Disagree boarding
# 63327 arriving at ICU at 19986.0
# beds 616 611
# Became false! False 616
# Agreed not boarding
# 63327 left ward in 15.1 minutes.
# 5525 arriving at ICU at 20002.0
# beds 614 611
# Became false! False 614
# Agreed not boarding
# 17617 left ward in 34.6 minutes.
# 69248 arriving at ICU at 20019.0
# beds 613 611
# Disagree boarding
# 69248 left ward in 1.5 minutes.
# 21185 arriving at ICU at 20038.0
# beds 615 612
# Disagree boarding
# 17385 arriving at ICU at 20056.0
# beds 619 613
# Disagree boarding
# 1861 arriving at ICU at 20074.0
# beds 615 614
# Disagree boarding
# 31221 arriving at ICU at 20080.0
# beds 615 615
# Became false! False 615
# 615
# Disagree not boarding, boarding
# 92050 arriving at ICU at 20089.0
# beds 617 614
# Became false! False 617
# Agreed not boarding
# 4843 left ward in 154.6 minutes.
# 20075 arriving at ICU at 20103.0
# beds 615 615
# Became false! False 615
# 615
# Disagree not boarding, boarding
# 24302 arriving at ICU at 20110.0
# beds 614 614
# Agreed boarding
# 20075 left ward in 12.9 minutes.
# 5525 left ward in 116.9 minutes.
# 92050 left ward in 31.0 minutes.
# 98517 arriving at ICU at 20120.0
# beds 616 615
# Became false! False 616
# Agreed not boarding
# 1861 left ward in 47.3 minutes.
# 54421 arriving at ICU at 20128.0
# beds 616 615
# Became false! False 616
# Agreed not boarding
# 17385 left ward in 72.6 minutes.
# 98517 left ward in 16.4 minutes.
# 32119 arriving at ICU at 20141.0
# beds 621 615
# Became false! False 621
# Agreed not boarding
# 32119 left ward in 2.7 minutes.
# 54421 left ward in 19.8 minutes.
# 19592 arriving at ICU at 20155.0
# beds 619 615
# Disagree boarding
# 1542 arriving at ICU at 20161.0
# beds 618 616
# Became false! False 618
# Agreed not boarding
# 54923 left ward in 262.1 minutes.
# 1542 left ward in 14.3 minutes.
# 18739 arriving at ICU at 20181.0
# beds 618 616
# Became false! False 618
# Agreed not boarding
# 7427 arriving at ICU at 20190.0
# beds 617 616
# Disagree boarding
# 24302 left ward in 85.7 minutes.
# 27043 arriving at ICU at 20198.0
# beds 622 617
# Disagree boarding
# 18739 left ward in 30.4 minutes.
# 6539 arriving at ICU at 20213.0
# beds 620 618
# Became false! False 620
# 620
# Disagree not boarding, boarding
# 31221 left ward in 143.2 minutes.
# 48794 arriving at ICU at 20228.0
# beds 619 618
# Became false! False 619
# Agreed not boarding
# 7427 left ward in 46.4 minutes.
# 75864 arriving at ICU at 20241.0
# beds 619 618
# Disagree boarding
# 48794 left ward in 22.2 minutes.
# 516 arriving at ICU at 20251.0
# beds 624 619
# Became false! False 624
# Agreed not boarding
# 27729 left ward in 311.2 minutes.
# 516 left ward in 4.8 minutes.
# 89085 arriving at ICU at 20256.0
# beds 622 619
# Disagree boarding
# 31300 arriving at ICU at 20266.0
# beds 620 620
# Agreed boarding
# 5367 left ward in 309.5 minutes.
# 4812 arriving at ICU at 20275.0
# beds 621 620
# Disagree boarding
# 89085 left ward in 34.0 minutes.
# 21939 arriving at ICU at 20294.0
# beds 622 621
# Agreed boarding
# 21939 left ward in 1.3 minutes.
# 21185 left ward in 266.7 minutes.
# 42460 arriving at ICU at 20308.0
# beds 625 621
# Disagree boarding
# 81737 arriving at ICU at 20313.0
# beds 623 622
# Became false! False 623
# Agreed not boarding
# 75864 left ward in 77.3 minutes.
# 43543 arriving at ICU at 20320.0
# beds 628 622
# Became false! False 628
# Agreed not boarding
# 4812 left ward in 45.3 minutes.
# 19592 left ward in 169.9 minutes.
# 32072 arriving at ICU at 20326.0
# beds 624 622
# Disagree boarding
# 81737 left ward in 23.2 minutes.
# 48363 arriving at ICU at 20337.0
# beds 624 623
# Disagree boarding
# 402 arriving at ICU at 20351.0
# beds 626 624
# Became false! False 626
# 626
# Disagree not boarding, boarding
# 48363 left ward in 24.4 minutes.
# 43543 left ward in 49.4 minutes.
# 32072 left ward in 44.0 minutes.
# 23371 arriving at ICU at 20371.0
# beds 624 623
# Became false! False 624
# Agreed not boarding
# 11722 arriving at ICU at 20379.0
# beds 624 623
# Disagree boarding
# 42460 left ward in 86.9 minutes.
# 16560 arriving at ICU at 20399.0
# beds 626 624
# Disagree boarding
# 402 left ward in 52.9 minutes.
# 15749 arriving at ICU at 20412.0
# beds 629 626
# Disagree boarding
# 74289 arriving at ICU at 20422.0
# beds 631 627
# Became false! False 631
# Agreed not boarding
# 25105 arriving at ICU at 20427.0
# beds 628 627
# Disagree boarding
# 16560 left ward in 32.4 minutes.
# 15749 left ward in 24.0 minutes.
# 74289 left ward in 22.6 minutes.
# 430 arriving at ICU at 20446.0
# beds 631 628
# Disagree boarding
# 1457 arriving at ICU at 20455.0
# beds 630 629
# Disagree boarding
# 430 left ward in 12.8 minutes.
# 27043 left ward in 261.9 minutes.
# 95540 arriving at ICU at 20464.0
# beds 631 630
# Became false! False 631
# Agreed not boarding
# 95540 left ward in 0.8 minutes.
# 7487 arriving at ICU at 20479.0
# beds 631 630
# Became false! False 631
# Agreed not boarding
# 9407 arriving at ICU at 20499.0
# beds 631 630
# Became false! False 631
# Agreed not boarding
# 6539 left ward in 295.0 minutes.
# 23371 left ward in 137.7 minutes.
# 7487 left ward in 32.2 minutes.
# 16800 arriving at ICU at 20518.0
# beds 632 631
# Disagree boarding
# 31300 left ward in 255.3 minutes.
# 1457 left ward in 71.3 minutes.
# 25105 left ward in 101.5 minutes.
# 40277 arriving at ICU at 20534.0
# beds 634 632
# Became false! False 634
# Agreed not boarding
# 3598 arriving at ICU at 20550.0
# beds 635 632
# Disagree boarding
# 18657 arriving at ICU at 20560.0
# beds 636 633
# Disagree boarding
# 40277 left ward in 30.3 minutes.
# 954 arriving at ICU at 20569.0
# beds 638 634
# Disagree boarding
# 96686 arriving at ICU at 20577.0
# beds 640 635
# Disagree boarding
# 3764 arriving at ICU at 20586.0
# beds 637 636
# Became false! False 637
# Agreed not boarding
# 3598 left ward in 38.2 minutes.
# 16800 left ward in 73.6 minutes.
# 9407 left ward in 97.4 minutes.
# 43456 arriving at ICU at 20603.0
# beds 643 636
# Became false! False 643
# Agreed not boarding
# 11722 left ward in 229.6 minutes.
# 96686 left ward in 42.5 minutes.
# 92052 arriving at ICU at 20623.0
# beds 639 636
# Disagree boarding
# 18657 left ward in 69.8 minutes.
# 23317 arriving at ICU at 20632.0
# beds 640 637
# Disagree boarding
# 43456 left ward in 32.3 minutes.
# 98517 arriving at ICU at 20649.0
# beds 639 638
# Became false! False 639
# Agreed not boarding
# 92052 left ward in 26.6 minutes.
# 23317 left ward in 20.4 minutes.
# 78842 arriving at ICU at 20660.0
# beds 641 638
# Disagree boarding
# 954 left ward in 93.3 minutes.
# 98517 left ward in 16.4 minutes.
# 26849 arriving at ICU at 20672.0
# beds 639 639
# Agreed boarding
# 78842 left ward in 15.1 minutes.
# 26789 arriving at ICU at 20687.0
# beds 639 639
# Became false! False 639
# 639
# Disagree not boarding, boarding
# 50628 arriving at ICU at 20706.0
# beds 641 638
# Disagree boarding
# 26789 left ward in 19.8 minutes.
# 93039 arriving at ICU at 20717.0
# beds 643 640
# Became false! False 643
# Agreed not boarding
# 1802 arriving at ICU at 20733.0
# beds 643 640
# Became false! False 643
# 643
# Disagree not boarding, boarding
# 26849 left ward in 74.2 minutes.
# 87628 arriving at ICU at 20752.0
# beds 642 639
# Disagree boarding
# 50628 left ward in 49.8 minutes.
# 91103 arriving at ICU at 20761.0
# beds 642 640
# Became false! False 642
# Agreed not boarding
# 27812 arriving at ICU at 20775.0
# beds 645 640
# Became false! False 645
# Agreed not boarding
# 1802 left ward in 44.3 minutes.
# 23451 arriving at ICU at 20783.0
# beds 646 641
# Disagree boarding
# 87628 left ward in 38.3 minutes.
# 27812 left ward in 21.5 minutes.
# 91103 left ward in 36.9 minutes.
# 61956 arriving at ICU at 20803.0
# beds 645 642
# Disagree boarding
# 93039 left ward in 96.8 minutes.
# 94103 arriving at ICU at 20823.0
# beds 644 643
# Became false! False 644
# 644
# Disagree not boarding, boarding
# 61956 left ward in 23.1 minutes.
# 23451 left ward in 46.0 minutes.
# 46484 arriving at ICU at 20836.0
# beds 646 642
# Disagree boarding
# 85608 arriving at ICU at 20844.0
# beds 649 643
# Became false! False 649
# Agreed not boarding
# 94103 left ward in 28.2 minutes.
# 63054 arriving at ICU at 20855.0
# beds 646 644
# Disagree boarding
# 46484 left ward in 21.9 minutes.
# 63054 left ward in 5.9 minutes.
# 5100 arriving at ICU at 20873.0
# beds 646 645
# Disagree boarding
# 15793 arriving at ICU at 20878.0
# beds 648 646
# Became false! False 648
# 648
# Disagree not boarding, boarding
# 25069 arriving at ICU at 20892.0
# beds 647 645
# Became false! False 647
# Agreed not boarding
# 5100 left ward in 23.5 minutes.
# 40205 arriving at ICU at 20906.0
# beds 647 645
# Disagree boarding
# 15793 left ward in 28.2 minutes.
# 40205 left ward in 14.0 minutes.
# 44820 arriving at ICU at 20925.0
# beds 653 647
# Disagree boarding
# 49340 arriving at ICU at 20939.0
# beds 648 648
# Agreed boarding
# 85608 left ward in 105.0 minutes.
# 49340 left ward in 13.0 minutes.
# 3588 arriving at ICU at 20958.0
# beds 656 648
# Disagree boarding
# 25069 left ward in 67.9 minutes.
# 29261 arriving at ICU at 20974.0
# beds 651 649
# Became false! False 651
# Agreed not boarding
# 18689 arriving at ICU at 20987.0
# beds 654 649
# Disagree boarding
# 44820 left ward in 65.8 minutes.
# 97060 arriving at ICU at 20994.0
# beds 653 650
# Disagree boarding
# 2984 arriving at ICU at 21006.0
# beds 652 651
# Disagree boarding
# 6908 arriving at ICU at 21014.0
# beds 653 652
# Became false! False 653
# Agreed not boarding
# 10356 arriving at ICU at 21024.0
# beds 654 652
# Became false! False 654
# Agreed not boarding
# 10514 arriving at ICU at 21038.0
# beds 654 652
# Became false! False 654
# Agreed not boarding
# 29261 left ward in 70.6 minutes.
# 18689 left ward in 58.7 minutes.
# 10356 left ward in 24.3 minutes.
# 65579 arriving at ICU at 21049.0
# beds 655 652
# Became false! False 655
# Agreed not boarding
# 44388 arriving at ICU at 21054.0
# beds 654 652
# Became false! False 654
# Agreed not boarding
# 44388 left ward in 1.7 minutes.
# 1715 arriving at ICU at 21064.0
# beds 653 652
# Became false! False 653
# Agreed not boarding
# 65579 left ward in 20.3 minutes.
# 10514 left ward in 32.2 minutes.
# 58247 arriving at ICU at 21075.0
# beds 664 652
# Became false! False 664
# Agreed not boarding
# 22914 arriving at ICU at 21089.0
# beds 656 652
# Disagree boarding
# 1715 left ward in 25.2 minutes.
# 97060 left ward in 99.4 minutes.
# 21435 arriving at ICU at 21106.0
# beds 655 653
# Disagree boarding
# 6908 left ward in 95.5 minutes.
# 73958 arriving at ICU at 21125.0
# beds 657 654
# Disagree boarding
# 22914 left ward in 44.1 minutes.
# 48676 arriving at ICU at 21134.0
# beds 659 655
# Disagree boarding
# 73958 left ward in 15.3 minutes.
# 2984 left ward in 135.5 minutes.
# 3764 left ward in 556.6 minutes.
# 7482 arriving at ICU at 21148.0
# beds 658 656
# Became false! False 658
# Agreed not boarding
# 21435 left ward in 44.7 minutes.
# 66015 arriving at ICU at 21162.0
# beds 658 656
# Became false! False 658
# Agreed not boarding
# 57753 arriving at ICU at 21180.0
# beds 658 656
# Became false! False 658
# Agreed not boarding
# 21013 arriving at ICU at 21193.0
# beds 660 656
# Disagree boarding
# 48676 left ward in 62.7 minutes.
# 30210 arriving at ICU at 21210.0
# beds 657 657
# Became false! False 657
# 657
# Disagree not boarding, boarding
# 66015 left ward in 65.1 minutes.
# 45320 arriving at ICU at 21228.0
# beds 659 656
# Agreed boarding
# 95843 arriving at ICU at 21243.0
# beds 659 656
# Became false! False 659
# Agreed not boarding
# 7482 left ward in 98.6 minutes.
# 2477 arriving at ICU at 21261.0
# beds 657 656
# Disagree boarding
# 95843 left ward in 24.4 minutes.
# 28140 arriving at ICU at 21275.0
# beds 658 657
# Disagree boarding
# 23450 arriving at ICU at 21293.0
# beds 660 658
# Disagree boarding
# 83690 arriving at ICU at 21298.0
# beds 660 659
# Disagree boarding
# 74440 arriving at ICU at 21307.0
# beds 661 660
# Became false! False 661
# Agreed not boarding
# 55973 arriving at ICU at 21320.0
# beds 661 660
# Disagree boarding
# 45320 left ward in 97.9 minutes.
# 31216 arriving at ICU at 21327.0
# beds 663 661
# Disagree boarding
# 74440 left ward in 20.9 minutes.
# 28140 left ward in 54.2 minutes.
# 2477 left ward in 75.2 minutes.
# 83690 left ward in 42.5 minutes.
# 15858 arriving at ICU at 21341.0
# beds 664 662
# Disagree boarding
# 55973 left ward in 22.0 minutes.
# 28650 arriving at ICU at 21352.0
# beds 665 663
# Became false! False 665
# Agreed not boarding
# 3588 left ward in 406.3 minutes.
# 63135 arriving at ICU at 21366.0
# beds 670 663
# Became false! False 670
# Agreed not boarding
# 15858 left ward in 33.9 minutes.
# 63135 left ward in 9.8 minutes.
# 30210 left ward in 166.8 minutes.
# 17267 arriving at ICU at 21380.0
# beds 666 664
# Became false! False 666
# Agreed not boarding
# 57753 left ward in 208.9 minutes.
# 5465 arriving at ICU at 21393.0
# beds 668 664
# Disagree boarding
# 28650 left ward in 44.8 minutes.
# 31216 left ward in 76.9 minutes.
# 83292 arriving at ICU at 21406.0
# beds 672 665
# Disagree boarding
# 17267 left ward in 38.5 minutes.
# 6652 arriving at ICU at 21426.0
# beds 668 666
# Became false! False 668
# Agreed not boarding
# 58247 left ward in 359.9 minutes.
# 5465 left ward in 42.5 minutes.
# 97164 arriving at ICU at 21439.0
# beds 670 666
# Disagree boarding
# 83292 left ward in 41.2 minutes.
# 11107 arriving at ICU at 21450.0
# beds 669 667
# Became false! False 669
# 669
# Disagree not boarding, boarding
# 11107 left ward in 0.5 minutes.
# 88116 arriving at ICU at 21457.0
# beds 670 667
# Disagree boarding
# 61128 arriving at ICU at 21463.0
# beds 671 668
# Disagree boarding
# 61128 left ward in 6.6 minutes.
# 88116 left ward in 16.5 minutes.
# 28140 arriving at ICU at 21478.0
# beds 670 669
# Disagree boarding
# 6652 left ward in 57.1 minutes.
# 50628 arriving at ICU at 21495.0
# beds 673 670
# Disagree boarding
# 15853 arriving at ICU at 21503.0
# beds 674 671
# Disagree boarding
# 78416 arriving at ICU at 21509.0
# beds 674 672
# Became false! False 674
# Agreed not boarding
# 1026 arriving at ICU at 21525.0
# beds 673 672
# Became false! False 673
# 673
# Disagree not boarding, boarding
# 28140 left ward in 54.2 minutes.
# 67471 arriving at ICU at 21533.0
# beds 676 671
# Disagree boarding
# 50628 left ward in 49.8 minutes.
# 65359 arriving at ICU at 21551.0
# beds 673 672
# Disagree boarding
# 15853 left ward in 66.1 minutes.
# 2961 arriving at ICU at 21570.0
# beds 676 673
# Disagree boarding
# 97164 left ward in 132.9 minutes.
# 76682 arriving at ICU at 21578.0
# beds 676 674
# Became false! False 676
# Agreed not boarding
# 69295 arriving at ICU at 21583.0
# beds 675 674
# Became false! False 675
# Agreed not boarding
# 1026 left ward in 59.6 minutes.
# 14461 arriving at ICU at 21598.0
# beds 677 675
# Agreed boarding
# 21013 left ward in 405.5 minutes.
# 675

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
df['remaining_beds'].hist(bins = 100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pd.Series(agreementStore).value_counts()
# Out:
# Disagree boarding        675
# Agreed not boarding      659
# Disagree not boarding    208
# Agreed boarding          183
# dtype: int64

# %%
plt.figure()
df['counter_mort'] = np.random.lognormal(mean=0.3, sigma=1)
df['counter_mort'] = df['counter_mort'].apply(lambda x: (1 if x > 1 else x))
df['counter_mort'].hist(bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.columns
# Out:
# Index(['transfers.subject_id', 'transfers.hadm_id', 'transfers.icustay_id',
#        'transfers.eventtype', 'team_census', 'blocked_count', 'remaining_beds',
#        'icustay_los_total', 'icustay_los_boarder', 'icustay_boarder_initial',
#        ...
#        'sofa_cardiovascular', 'sofa_cns', 'sofa_renal', 'days_survived_dt',
#        'days_survived_dt2', 'time_diff',
#        'icustay_outtime_deathtime_difference', 'counter_mort',
#        'predicted_boarded', 'mort'],
#       dtype='object', length=135)
