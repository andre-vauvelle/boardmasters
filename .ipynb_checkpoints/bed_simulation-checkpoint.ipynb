# %% [markdown]
# # Bed simulation

# %%
"""
Bed counter-factual Simulation

Covers:

- Resources: Resource
- Resources: Container
- Waiting for other processes

Scenario:
    We are trying to assess if using a non-greedy approach would
     reduce the number of patients boarded to the wrong ward

- A patient arrives at the beds_correct - the logic!
beds = simulated_beds + remaining_beds

# If there are no beds in the correct specialty area irl
if remaining_beds=0:
    boarded = True
else:
    boarded = False
# If there are no beds in the simulation for the correct specialty area
if beds > 0 | predicted_board:
    simulation_boarded = True
else:
    simulation_boarded = False

if simulation_boarded & boarded:
    wait for a bit
    leave
if simulation_boarded & not boarded:
    increment simulated beds
    wait for a bit
    leave
if not simulation_boarded & boarded:
    decrement simulation beds
    wait for a bit
if not simulation_boarded & not boarded:  # repeated for readability...
    wait for a bit
    leave
"""
import itertools
import random
import pandas as pd

import simpy


RANDOM_SEED = 42
T_INTER = [5, 20]        # Create a patient every [min, max] minutes
SIM_TIME = 60*12*7          # Simulation time in minutes
NUMBER_OF_BEDS = 200

df = pd.read_csv('data.csv')
df['predicted_boarded'] = False
patients = df.to_dict(orient='records')

# Toy data
#patients = [{'transfers.subject_id': 1, 'icustay_los_total': 50, 'remaining_beds': 6, 'predicted_boarded': False},
#            {'transfers.subject_id': 2, 'icustay_los_total': 30, 'remaining_beds': 6, 'predicted_boarded': False}]


global simulated_beds
simulated_beds = 10
mortalityStore = []
agreementStore = []

def patient(env, beds_correct, **p):
    global simulated_beds
    print('%s arriving at ICU at %.1f' % (p['transfers.subject_id'], env.now))

    beds = simulated_beds + p['remaining_beds']
    if p['remaining_beds'] == 0:
        boarded = True
    else:
        boarded = False

    # If there are no beds in the simulation for the correct specialty area
    if beds < 0 | p['predicted_boarded']:
        simulation_boarded = True
        print("Decision made")
        print(beds)
    else:
        simulation_boarded = False

    if simulation_boarded & boarded:
        print("Agreed boarding")
        agreementStore.append("Agreed boarding")
        mortalityStore.append(p['days_survived'])
        with beds_correct.request() as req:
            start = env.now
            # Request one of the beds
            yield req
            # Stay in a bed for a bit
            yield env.timeout(p['icustay_los_total'])

            print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))
    elif simulation_boarded & (not boarded):
        print("Disagree boarding")
        agreementStore.append("Disagree boarding")
        mortalityStore.append(p['days_survived'])
        with beds_correct.request() as req:
            start = env.now
            simulated_beds += 1
            # Request one of the beds
            yield req
            # Stay in a bed for a bit
            yield env.timeout(p['icustay_los_total'])
            #simulated_beds -= 1

            print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))
    elif (not simulation_boarded) and boarded:
        print("Disagree not boarding")
        agreementStore.append("Disagree not boarding")
        mortalityStore.append(p['days_survived'])
        with beds_correct.request() as req:
            start = env.now
            simulated_beds -= 1
            # Request one of the beds
            yield req
            # Stay in a bed for a bit
            yield env.timeout(p['icustay_los_total'])
            #simulated_beds += 1

            print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))
    elif simulation_boarded and boarded:
        print("Agreed not boarding")
        agreementStore.append("Agreed not boarding")
        mortalityStore.append(p['days_survived'])
        with beds_correct.request() as req:
            start = env.now
            # Request one of the beds
            yield req
            # Stay in a bed for a bit
            yield env.timeout(p['icustay_los_total'])

            print('%s left ward in %.1f minutes.' % (p['transfers.subject_id'], env.now - start))




def patient_generator(env, beds_correct, patients):
    """Generate new patient that arrive at the ICU."""
    for i in itertools.count():
        yield env.timeout(random.randint(*T_INTER))
        p = random.sample(patients, 1)[0]
        #print_name = 'Simulation id {}'.format(i) #, Data id  %s' % (i, p['transfers.subject_id'])
        env.process(patient(env, beds_correct, **p))


# Create environment and start processes
env = simpy.Environment()
beds_correct = simpy.Resource(env, NUMBER_OF_BEDS)
#bed_boarded = simpy.Resource(env, 1, NUMBER_OF_BEDS)
env.process(patient_generator(env, beds_correct, patients)) #beds_boarded,

# Execute!
env.run(until=SIM_TIME)

print(simulated_beds)
# Out:
# /Users/andrevauvelle/anaconda3/envs/flask/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 16194 arriving at ICU at 9.0
# Disagree not boarding
# 936 arriving at ICU at 16.0
# 80117 arriving at ICU at 26.0
# 24712 arriving at ICU at 42.0
# 16194 left ward in 33.6 minutes.
# 71814 arriving at ICU at 51.0
# 25245 arriving at ICU at 70.0
# 11286 arriving at ICU at 77.0
# Disagree not boarding
# 13848 arriving at ICU at 86.0
# 55909 arriving at ICU at 103.0
# 46254 arriving at ICU at 121.0
# Disagree not boarding
# 28206 arriving at ICU at 130.0
# 46254 left ward in 21.5 minutes.
# 9412 arriving at ICU at 143.0
# 11286 left ward in 73.1 minutes.
# 32072 arriving at ICU at 155.0
# 42763 arriving at ICU at 160.0
# 98435 arriving at ICU at 171.0
# 66603 arriving at ICU at 182.0
# 6155 arriving at ICU at 196.0
# 94503 arriving at ICU at 208.0
# Disagree not boarding
# 12540 arriving at ICU at 225.0
# 95765 arriving at ICU at 237.0
# 1332 arriving at ICU at 244.0
# 46817 arriving at ICU at 260.0
# 65481 arriving at ICU at 269.0
# 59255 arriving at ICU at 287.0
# 88081 arriving at ICU at 297.0
# 1899 arriving at ICU at 304.0
# 1554 arriving at ICU at 311.0
# 25073 arriving at ICU at 324.0
# 6838 arriving at ICU at 330.0
# Disagree not boarding
# 97476 arriving at ICU at 347.0
# 96149 arriving at ICU at 361.0
# 75618 arriving at ICU at 379.0
# 6838 left ward in 57.5 minutes.
# 9249 arriving at ICU at 396.0
# 31282 arriving at ICU at 405.0
# 45193 arriving at ICU at 412.0
# 98853 arriving at ICU at 419.0
# 94503 left ward in 215.0 minutes.
# 17671 arriving at ICU at 430.0
# 66244 arriving at ICU at 445.0
# 45213 arriving at ICU at 452.0
# 27437 arriving at ICU at 470.0
# 27899 arriving at ICU at 476.0
# 78532 arriving at ICU at 483.0
# 83151 arriving at ICU at 491.0
# 45056 arriving at ICU at 497.0
# 13439 arriving at ICU at 507.0
# 15485 arriving at ICU at 512.0
# 24993 arriving at ICU at 1368.0
# 16847 arriving at ICU at 1383.0
# 28238 arriving at ICU at 1390.0
# Decision made
# -1
# Agreed boarding
# 67788 arriving at ICU at 1406.0
# 41976 arriving at ICU at 1412.0
# 19763 arriving at ICU at 1425.0
# 69912 arriving at ICU at 1430.0
# Decision made
# -1
# Agreed boarding
# 69912 left ward in 18.3 minutes.
# 28410 arriving at ICU at 1449.0
# 28238 left ward in 60.3 minutes.
# 85404 arriving at ICU at 1457.0
# 15852 arriving at ICU at 1465.0
# 1329 arriving at ICU at 1473.0
# Decision made
# -1
# Agreed boarding
# 25874 arriving at ICU at 1479.0
# 22847 arriving at ICU at 1488.0
# 61128 arriving at ICU at 1505.0
# 29299 arriving at ICU at 1512.0
# 2366 arriving at ICU at 1519.0
# 1329 left ward in 47.2 minutes.
# 22811 arriving at ICU at 1526.0
# 14423 arriving at ICU at 1545.0
# 50882 arriving at ICU at 1552.0
# 4888 arriving at ICU at 1560.0
# 5767 arriving at ICU at 1579.0
# 78010 arriving at ICU at 1589.0
# 94821 arriving at ICU at 1606.0
# 64249 arriving at ICU at 1611.0
# 19640 arriving at ICU at 1629.0
# 24975 arriving at ICU at 1645.0
# 31026 arriving at ICU at 1655.0
# 81476 arriving at ICU at 1668.0
# Decision made
# -1
# Agreed boarding
# 3939 arriving at ICU at 1677.0
# 40762 arriving at ICU at 1689.0
# 81476 left ward in 21.9 minutes.
# 71924 arriving at ICU at 1709.0
# 6898 arriving at ICU at 1729.0
# Decision made
# -1
# Agreed boarding
# 31519 arriving at ICU at 1736.0
# Decision made
# -1
# Agreed boarding
# 15485 arriving at ICU at 1753.0
# Decision made
# -1
# Agreed boarding
# 22990 arriving at ICU at 1771.0
# 15485 left ward in 18.9 minutes.
# 2136 arriving at ICU at 1783.0
# 31519 left ward in 47.5 minutes.
# 57654 arriving at ICU at 1800.0
# 91614 arriving at ICU at 1820.0
# 96386 arriving at ICU at 1836.0
# 65759 arriving at ICU at 1851.0
# 20518 arriving at ICU at 1864.0
# 47532 arriving at ICU at 1869.0
# 6898 left ward in 148.6 minutes.
# 3362 arriving at ICU at 1881.0
# 6613 arriving at ICU at 1894.0
# 57260 arriving at ICU at 1914.0
# 18055 arriving at ICU at 1926.0
# 28211 arriving at ICU at 1934.0
# 30105 arriving at ICU at 1946.0
# 25515 arriving at ICU at 1952.0
# 56703 arriving at ICU at 1969.0
# 20086 arriving at ICU at 1979.0
# 47287 arriving at ICU at 1991.0
# 3143 arriving at ICU at 2007.0
# 16091 arriving at ICU at 2023.0
# 93840 arriving at ICU at 2034.0
# 19991 arriving at ICU at 2048.0
# 4328 arriving at ICU at 2068.0
# 6378 arriving at ICU at 2075.0
# 25399 arriving at ICU at 2087.0
# 90020 arriving at ICU at 2092.0
# 50906 arriving at ICU at 2097.0
# 14676 arriving at ICU at 2108.0
# 20212 arriving at ICU at 2123.0
# 6718 arriving at ICU at 2138.0
# 9216 arriving at ICU at 2829.0
# 12834 arriving at ICU at 2849.0
# 68001 arriving at ICU at 2863.0
# Decision made
# -1
# Agreed boarding
# 92872 arriving at ICU at 2883.0
# 68001 left ward in 25.6 minutes.
# 10236 arriving at ICU at 2896.0
# Decision made
# -1
# Agreed boarding
# 21240 arriving at ICU at 2913.0
# Decision made
# -1
# Agreed boarding
# 10236 left ward in 25.3 minutes.
# 63785 arriving at ICU at 2929.0
# 21240 left ward in 20.8 minutes.
# 21443 arriving at ICU at 2945.0
# 5130 arriving at ICU at 2964.0
# 80015 arriving at ICU at 2977.0
# 29695 arriving at ICU at 2996.0
# 30344 arriving at ICU at 3008.0
# 17181 arriving at ICU at 3014.0
# 9648 arriving at ICU at 3022.0
# 72487 arriving at ICU at 3038.0
# 6898 arriving at ICU at 3050.0
# Decision made
# -1
# Agreed boarding
# 74039 arriving at ICU at 3067.0
# 27167 arriving at ICU at 3087.0
# Decision made
# -1
# Agreed boarding
# 41976 arriving at ICU at 3107.0
# 67323 arriving at ICU at 3114.0
# 27167 left ward in 27.2 minutes.
# 96324 arriving at ICU at 3120.0
# 13556 arriving at ICU at 3129.0
# 19641 arriving at ICU at 3148.0
# 24569 arriving at ICU at 3158.0
# 14116 arriving at ICU at 3169.0
# 75557 arriving at ICU at 3175.0
# 78819 arriving at ICU at 3182.0
# 16807 arriving at ICU at 3193.0
# 6898 left ward in 148.6 minutes.
# 47748 arriving at ICU at 3206.0
# 9811 arriving at ICU at 3213.0
# Decision made
# -1
# Agreed boarding
# 67976 arriving at ICU at 3230.0
# 31175 arriving at ICU at 3245.0
# 9811 left ward in 34.1 minutes.
# 1357 arriving at ICU at 3264.0
# 12530 arriving at ICU at 3282.0
# 16992 arriving at ICU at 3300.0
# 11255 arriving at ICU at 3309.0
# 11342 arriving at ICU at 3317.0
# 53842 arriving at ICU at 3331.0
# 29767 arriving at ICU at 3349.0
# 91877 arriving at ICU at 3366.0
# 4268 arriving at ICU at 3386.0
# 31062 arriving at ICU at 3396.0
# 16349 arriving at ICU at 3413.0
# Decision made
# -1
# Agreed boarding
# 4458 arriving at ICU at 3430.0
# Decision made
# -1
# Agreed boarding
# 50877 arriving at ICU at 3447.0
# 16349 left ward in 37.8 minutes.
# 4458 left ward in 23.7 minutes.
# 5631 arriving at ICU at 3459.0
# 30344 arriving at ICU at 3479.0
# 2223 arriving at ICU at 3495.0
# 43107 arriving at ICU at 3510.0
# 31593 arriving at ICU at 3524.0
# 11003 arriving at ICU at 3544.0
# 15083 arriving at ICU at 3556.0
# 80861 arriving at ICU at 3570.0
# 30442 arriving at ICU at 3585.0
# Decision made
# -1
# Agreed boarding
# 10017 arriving at ICU at 3603.0
# 80536 arriving at ICU at 3614.0
# 70516 arriving at ICU at 3625.0
# 61794 arriving at ICU at 3645.0
# 17970 arriving at ICU at 3651.0
# 45320 arriving at ICU at 3658.0
# 30442 left ward in 74.1 minutes.
# 15268 arriving at ICU at 3675.0
# 19749 arriving at ICU at 3680.0
# 23128 arriving at ICU at 3691.0
# 28386 arriving at ICU at 3697.0
# 83854 arriving at ICU at 3703.0
# 57981 arriving at ICU at 3709.0
# 30950 arriving at ICU at 3720.0
# 85899 arriving at ICU at 3736.0
# 13927 arriving at ICU at 3753.0
# 27680 arriving at ICU at 3758.0
# Decision made
# -1
# Agreed boarding
# 92800 arriving at ICU at 3774.0
# 20217 arriving at ICU at 3793.0
# 27680 left ward in 47.7 minutes.
# 55273 arriving at ICU at 3813.0
# 18557 arriving at ICU at 3829.0
# 10149 arriving at ICU at 3842.0
# 3021 arriving at ICU at 3856.0
# 5681 arriving at ICU at 3873.0
# Decision made
# -1
# Agreed boarding
# 24912 arriving at ICU at 3883.0
# 5681 left ward in 15.8 minutes.
# 26192 arriving at ICU at 3895.0
# 30393 arriving at ICU at 3906.0
# 99454 arriving at ICU at 3924.0
# 979 arriving at ICU at 3929.0
# 14855 arriving at ICU at 3949.0
# 936 arriving at ICU at 3959.0
# 28650 arriving at ICU at 3971.0
# 31057 arriving at ICU at 3985.0
# 62530 arriving at ICU at 4003.0
# 84531 arriving at ICU at 4019.0
# 25348 arriving at ICU at 4032.0
# 42870 arriving at ICU at 4051.0
# 11469 arriving at ICU at 4068.0
# Decision made
# -1
# Agreed boarding
# 98950 arriving at ICU at 4073.0
# 11469 left ward in 13.9 minutes.
# 31831 arriving at ICU at 4089.0
# Decision made
# -1
# Agreed boarding
# 12078 arriving at ICU at 4103.0
# 7266 arriving at ICU at 4123.0
# 31193 arriving at ICU at 4138.0
# 31225 arriving at ICU at 4153.0
# 41962 arriving at ICU at 4166.0
# 17019 arriving at ICU at 4177.0
# Decision made
# -1
# Agreed boarding
# 31831 left ward in 92.2 minutes.
# 6447 arriving at ICU at 4189.0
# Decision made
# -1
# Agreed boarding
# 17019 left ward in 27.3 minutes.
# 47726 arriving at ICU at 4206.0
# 6447 left ward in 21.0 minutes.
# 2771 arriving at ICU at 4215.0
# 40923 arriving at ICU at 4235.0
# 74022 arriving at ICU at 4248.0
# Decision made
# -1
# Agreed boarding
# 65732 arriving at ICU at 4265.0
# 21820 arriving at ICU at 4271.0
# 74022 left ward in 33.3 minutes.
# 25886 arriving at ICU at 4286.0
# 57535 arriving at ICU at 4306.0
# Decision made
# -1
# Agreed boarding
# 19390 arriving at ICU at 4320.0
# 40370 arriving at ICU at 4330.0
# Decision made
# -1
# Agreed boarding
# 87989 arriving at ICU at 4338.0
# 29275 arriving at ICU at 4347.0
# 51669 arriving at ICU at 4357.0
# 25874 arriving at ICU at 4364.0
# 26004 arriving at ICU at 4380.0
# 57535 left ward in 77.4 minutes.
# 74640 arriving at ICU at 4394.0
# 60954 arriving at ICU at 4409.0
# 40440 arriving at ICU at 4422.0
# 40370 left ward in 92.2 minutes.
# 13273 arriving at ICU at 4441.0
# 6053 arriving at ICU at 4461.0
# 88411 arriving at ICU at 4468.0
# 95976 arriving at ICU at 4479.0
# 63922 arriving at ICU at 4487.0
# Decision made
# -1
# Agreed boarding
# 72230 arriving at ICU at 4501.0
# 17131 arriving at ICU at 4507.0
# 23070 arriving at ICU at 4516.0
# Decision made
# -1
# Agreed boarding
# 23070 left ward in 1.0 minutes.
# 71089 arriving at ICU at 4531.0
# 16260 arriving at ICU at 4550.0
# 20560 arriving at ICU at 4565.0
# 63922 left ward in 80.1 minutes.
# 92331 arriving at ICU at 4572.0
# 20144 arriving at ICU at 4587.0
# 6572 arriving at ICU at 4602.0
# 82847 arriving at ICU at 4607.0
# 24172 arriving at ICU at 4620.0
# 17922 arriving at ICU at 4630.0
# 9908 arriving at ICU at 4650.0
# 78306 arriving at ICU at 4659.0
# 69624 arriving at ICU at 4677.0
# 89868 arriving at ICU at 4695.0
# 505 arriving at ICU at 4712.0
# 22990 arriving at ICU at 4718.0
# 1571 arriving at ICU at 4734.0
# 21904 arriving at ICU at 4749.0
# 453 arriving at ICU at 4754.0
# 26277 arriving at ICU at 4766.0
# 45604 arriving at ICU at 4782.0
# 11507 arriving at ICU at 4791.0
# Decision made
# -1
# Agreed boarding
# 11507 left ward in 13.3 minutes.
# 96629 arriving at ICU at 4808.0
# 19012 arriving at ICU at 4822.0
# Decision made
# -1
# Agreed boarding
# 5259 arriving at ICU at 4829.0
# 32639 arriving at ICU at 4843.0
# 52288 arriving at ICU at 4862.0
# 14994 arriving at ICU at 4880.0
# 93209 arriving at ICU at 4895.0
# Decision made
# -1
# Agreed boarding
# 19012 left ward in 82.1 minutes.
# 21623 arriving at ICU at 4911.0
# 69624 arriving at ICU at 4921.0
# 26569 arriving at ICU at 4926.0
# 93209 left ward in 36.3 minutes.
# 14757 arriving at ICU at 4938.0
# 2375 arriving at ICU at 4949.0
# Decision made
# -1
# Agreed boarding
# 2375 left ward in 2.6 minutes.
# 13848 arriving at ICU at 4959.0
# 4260 arriving at ICU at 4975.0
# Decision made
# -1
# Agreed boarding
# 29003 arriving at ICU at 4992.0
# 5495 arriving at ICU at 4998.0
# 2172 arriving at ICU at 5006.0
# Decision made
# -1
# Agreed boarding
# 12896 arriving at ICU at 5012.0
# 81202 arriving at ICU at 5030.0
# -1

# %%
df.
# Out:
# ['Disagree not boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding',
#  'Agreed boarding']

# %%
# %matplotlib notebook
import matlplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-683e3d0d7e07> in <module>()
# ----> 1 get_ipython().run_line_magic('matplotlib', 'notebook')
#       2 import matlplotlib.pyplot as plt
#
# ~/anaconda3/envs/flask/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2129                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(*args,**kwargs)
#    2132             return result
#    2133
#
# <decorator-gen-107> in matplotlib(self, line)
#
# ~/anaconda3/envs/flask/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda3/envs/flask/lib/python3.6/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/anaconda3/envs/flask/lib/python3.6/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3035         """
#    3036         from IPython.core import pylabtools as pt
# -> 3037         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3038
#    3039         if gui != 'inline':
#
# ~/anaconda3/envs/flask/lib/python3.6/site-packages/IPython/core/pylabtools.py in find_gui_and_backend(gui, gui_select)
#     271     """
#     272
# --> 273     import matplotlib
#     274
#     275     if gui and gui != 'auto':
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df['remaining_beds'].hist()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-fdb3303578c1> in <module>()
# ----> 1 df['remaining_beds'].hist()
#
# ~/anaconda3/envs/flask/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2461
#    2462     """
# -> 2463     import matplotlib.pyplot as plt
#    2464
#    2465     if by is None:
#
# ModuleNotFoundError: No module named 'matplotlib'
